# %%
from elevation_analysis import run_fire_elevation_analysis_by_date
run_fire_elevation_analysis_by_date('Monument Rock', '1989-07-28')
# Out:
# FIRE SEVERITY + ELEVATION ANALYSIS BY DATE
# ==================================================
# Searching for fire data file...
# Found fire data at: ../downloaded_data/mnf_fires_all.geojson
# Loading fire data to find 'Monument Rock'...
# Found: Monument Rock (1989)
#
# Selected Fire: Monument Rock (1989-ORWWF-000377)
# Fire Year: 1989
# Fire Date: 1989-07-28
# Fire Area: 0.00575968 square degrees
#
# Analysis Timeline:
# Fire date: 1989-07-28
# Pre-fire target: 1989-06-28 (30 days before)
# Post-fire target: 1990-07-28 (365 days after)
# Satellite: LANDSAT-5
#
# Searching for pre-fire imagery...
# Attempt 1: Searching with +/-30 day buffer...
# Searching LANDSAT-5 imagery from 1989-05-29 to 1989-07-28
# Found 2 images
#   Image 1: 1989-07-28, 0.0% clouds, 30 days from target
#   Image 2: 1989-06-10, 7.0% clouds, 18 days from target
#
# Calculating pre-fire NBR...
# Processing LANDSAT-5 image from: 1989-07-28T18:05:01.513094Z
# Cloud cover: 0.0%
# Using NIR: nir08, SWIR2: swir22
# Valid pixels: 57452/97016 (59.2%)
# NBR calculated successfully
# Pre-fire NBR: Mean 0.318
#
# Searching for post-fire imagery...
# Attempt 1: Searching with +/-30 day buffer...
# Searching LANDSAT-5 imagery from 1990-06-28 to 1990-08-27
# Found 1 images
#   Image 1: 1990-08-16, 14.0% clouds, 19 days from target
#
# Calculating post-fire NBR...
# Processing LANDSAT-5 image from: 1990-08-16T17:57:51.912000Z
# Cloud cover: 14.0%
# Using NIR: nir08, SWIR2: swir22
# Valid pixels: 57452/97016 (59.2%)
# NBR calculated successfully
# Post-fire NBR: Mean 0.086
#
# Calculating dNBR...
# dNBR calculated successfully!
# Mean dNBR: 0.233
# Range: -0.463 to 1.081
# Total pixels: 57,452
#
# Burn Severity Classification:
# High Severity (>0.66):       2509 pixels (  4.4%)
# Moderate-High (0.44-0.66):  10862 pixels ( 18.9%)
# Moderate-Low (0.25-0.44):   12517 pixels ( 21.8%)
# Low Severity (0.1-0.25):    10476 pixels ( 18.2%)
# Unburned (<0.1):            21088 pixels ( 36.7%)
#
# Downloading elevation data...
# Downloading elevation data...
#   Downloaded 12 elevation points...
#   Downloaded 50 elevation points...
#   Downloaded 86 elevation points...
#   Downloaded 122 elevation points...
#   Downloaded 158 elevation points...
# Retrieved 185 elevation points
# Created elevation grid: (150, 150)
# Elevation range: 1325m to 2313m
#
# Analyzing fire severity vs elevation...
# Analyzing fire severity vs elevation relationship...
# Analyzing 57452 valid pixels
#
# Creating visualizations...
# FINAL ANALYSIS RESULTS
# ==============================
#
# Fire Information:
# Name: Monument Rock
# ID: 1989-ORWWF-000377
# Year: 1989
# Fire Date: 1989-07-28
# Satellite: LANDSAT-5
#
# Analysis Dates:
# Pre-fire imagery: 1989-06-28
# Post-fire imagery: 1990-07-28
#
# Spatial Analysis:
# Total analyzed pixels: 57,452
# Fire area: 0.00575968 square degrees
#
# Elevation Summary:
# Range: 1408 - 2313 m
# Mean: 1897 m
# Relief: 905 m
#
# Fire Severity Summary:
# dNBR Range: -0.463 - 1.081
# Mean dNBR: 0.233
#
# Elevation-Fire Severity Correlation:
# Pearson correlation: 0.0095
# P-value: 0.022800
# Statistical significance: Yes (α=0.05)
#
# Interpretation:
# There is a weak positive correlation between elevation and fire severity.
# Elevation does not strongly influence fire severity in this fire.
#
# Detailed Severity by Elevation Zones:
# Elevation (m) Mean dNBR  High Sev %  Mod-High %  Pixels
# -----------------------------------------------------------------
# 1465         0.023      0.0         1.2         2576
# 1578         0.130      1.0         10.3        4077
# 1691         0.326      7.1         27.8        7829
# 1804         0.286      6.7         24.0        12191
# 1917         0.209      4.8         18.4        8839
# 2030         0.227      3.2         18.6        9247
# 2143         0.283      4.5         22.2        6413
# 2256         0.158      1.4         8.6         6280
#
# Analysis complete!
# {'fire_info': {'geometry': <POLYGON ((-118.255 44.33, -118.255 44.33, -118.255 44.33, -118.255 44.33, -...>,
#   'fire_id': '1989-ORWWF-000377',
#   'incident_name': 'Monument Rock',
#   'fire_year': 1989,
#   'fire_date': Timestamp('1989-07-28 00:00:00')},
#  'analysis_dates': {'pre_fire': Timestamp('1989-06-28 00:00:00'),
#   'post_fire': Timestamp('1990-07-28 00:00:00')},
#  'pre_fire_nbr': <xarray.DataArray (band: 1, y: 362, x: 268)> Size: 776kB
#  dask.array<getitem, shape=(1, 362, 268), dtype=float64, chunksize=(1, 362, 213), chunktype=numpy.ndarray>
#  Coordinates:
#    * band         (band) int64 8B 1
#    * x            (x) float64 2kB 3.948e+05 3.949e+05 ... 4.028e+05 4.028e+05
#    * y            (y) float64 3kB 4.916e+06 4.916e+06 ... 4.905e+06 4.905e+06
#      spatial_ref  int64 8B 0,
#  'post_fire_nbr': <xarray.DataArray (band: 1, y: 362, x: 268)> Size: 776kB
#  dask.array<getitem, shape=(1, 362, 268), dtype=float64, chunksize=(1, 362, 175), chunktype=numpy.ndarray>
#  Coordinates:
#    * band         (band) int64 8B 1
#    * x            (x) float64 2kB 3.948e+05 3.949e+05 ... 4.028e+05 4.028e+05
#    * y            (y) float64 3kB 4.916e+06 4.916e+06 ... 4.905e+06 4.905e+06
#      spatial_ref  int64 8B 0,
#  'dnbr': <xarray.DataArray (band: 1, y: 362, x: 268)> Size: 776kB
#  dask.array<sub, shape=(1, 362, 268), dtype=float64, chunksize=(1, 362, 120), chunktype=numpy.ndarray>
#  Coordinates:
#    * band         (band) int64 8B 1
#    * x            (x) float64 2kB 3.948e+05 3.949e+05 ... 4.028e+05 4.028e+05
#    * y            (y) float64 3kB 4.916e+06 4.916e+06 ... 4.905e+06 4.905e+06
#      spatial_ref  int64 8B 0,
#  'elevation': <xarray.DataArray (y: 150, x: 150)> Size: 180kB
#  array([[1793.        , 1796.78422224, 1800.80433748, ..., 1662.        ,
#          1662.        , 1662.        ],
#         [1799.53069736, 1803.84246733, 1808.6430253 , ..., 1662.        ,
#          1662.        , 1662.        ],
#         [1805.99749284, 1809.62002828, 1815.37888994, ..., 1662.        ,
#          1662.        , 1662.        ],
#         ...,
#         [1463.        , 1463.        , 1463.        , ..., 1339.        ,
#          1339.        , 1339.        ],
#         [1463.        , 1463.        , 1538.        , ..., 1339.        ,
#          1339.        , 1339.        ],
#         [1463.        , 1538.        , 1538.        , ..., 1339.        ,
#          1339.        , 1339.        ]])
#  Coordinates:
#    * y            (y) float64 1kB 44.27 44.27 44.28 44.28 ... 44.41 44.41 44.41
#    * x            (x) float64 1kB -118.3 -118.3 -118.3 ... -118.2 -118.2 -118.2
#      spatial_ref  int64 8B 0,
#  'elevation_results': {'dnbr_values': array([0.36712429, 0.27958163, 0.12223445, ..., 0.28262326, 0.37937452,
#          0.2564088 ]),
#   'elevation_values': array([1520.42257927, 1520.42257927, 1519.42770806, ..., 2037.53577878,
#          2038.56367349, 2038.56367349]),
#   'correlation': np.float64(0.009498723529721422),
#   'p_value': np.float64(0.022800273935631474),
#   'elevation_bins': array([1464.53793746, 1577.61046359, 1690.68298972, 1803.75551586,
#          1916.82804199, 2029.90056813, 2142.97309426, 2256.04562039]),
#   'severity_by_elevation':      elevation  high_severity  moderate_high  moderate_low  low_severity  \
#   0  1464.537937       0.000000       1.203416      4.968944     10.481366
#   1  1577.610464       0.956586      10.326220     20.603385     17.414766
#   2  1690.682990       7.101801      27.806872     26.938306     18.827436
#   3  1803.755516       6.677057      23.984907     21.729144     16.495776
#   4  1916.828042       4.785609      18.361806     17.343591     15.703134
#   5  2029.900568       3.222667      18.633070     25.521791     17.443495
#   6  2142.973094       4.537658      22.220490     27.927647     19.678777
#   7  2256.045620       1.401274       8.566879     17.627389     27.834395
#
#       unburned  mean_dnbr  pixel_count
#   0  83.346273   0.023138         2576
#   1  50.699043   0.130039         4077
#   2  19.325584   0.325821         7829
#   3  31.113116   0.285522        12191
#   4  43.805860   0.209367         8839
#   5  35.178977   0.227184         9247
#   6  25.635428   0.282740         6413
#   7  44.570064   0.157921         6280  },
#  'satellite': 'landsat-5'}
