# %%
#Check which ones are needed
import geopandas as gpd
import fiona
import os
import zipfile
import rasterio
import numpy as np
from rasterio.features import rasterize
from rasterio.transform import from_origin
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import contextily as ctx
import ipywidgets as widgets
from IPython.display import display
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import matplotlib.patches as mpatches
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %%
# Update with cleaned fires
mnf_fires_all = gpd.read_file(r"../subsetted_data/mnf_fires_all.geojson")
mtbs_points = gpd.read_file(r"../subsetted_data/mnf_mtbs_pts.geojson")
mnf_bounds = gpd.read_file(r"../subsetted_data/malheur_bounds.geojson")

# %%
mnf_fires_all
# Out:
#      OBJECTID               MAP_METHOD      DATE_CUR  \
# 0       32469          Digitized-Other  200805290000
# 1        4509          Digitized-Other  200805290000
# 2        3335          Digitized-Other  200805290000
# 3        3326          Digitized-Other  200805290000
# 4       32192          Digitized-Other  200805290000
# ..        ...                      ...           ...
# 211     31393                    Other  202303081935
# 212     80841  IR Image Interpretation          2022
# 213      4237                    Other  202210172012
# 214     12304                    Other  202210172024
# 215      5017                    Other  202309231609
#
#                                  COMMENTS  \
# 0    Added from 1MM Scale recitifed image
# 1    Added from 1MM Scale recitifed image
# 2    Added from 1MM Scale recitifed image
# 3    Added from 1MM Scale recitifed image
# 4    Added from 1MM Scale recitifed image
# ..                                    ...
# 211                                  None
# 212                DRTI 09/15/2022 @ 1200
# 213                                  None
# 214                                  None
# 215                                  None
#
#                                      GEO_ID  \
# 0    {61D7987C-830C-4F28-BB5E-37F57D6EB9A6}
# 1    {41ECC8F1-8906-440D-8339-CA43F745789D}
# 2    {05EBF502-3A99-4DAD-90F1-334E43A9BB2A}
# 3    {C8DD94E6-A1D3-4862-8BDD-7E0D26B16DF5}
# 4    {E70A5124-AAFE-437E-A824-690872FB9F18}
# ..                                      ...
# 211  {A5773E46-548B-4332-AB2E-BB2B0374975C}
# 212  {EB946ACE-4C19-4487-94AA-28CF942C72F6}
# 213  {3AFD39B3-6A7E-4F58-8C8F-3BE55DF54D05}
# 214  {1B812AB1-E415-40A5-B2E6-282DABC2FFE8}
# 215  {74A2C0CB-9A37-451D-8AF1-20E82CFCEF31}
#
#                                     IRWINID         UNQE_FIRE_  FIRE_YEAR  \
# 0                                      None  1910-ORMAF-000028       1910
# 1                                      None  1910-ORMAF-000029       1910
# 2                                      None  1910-ORMAF-000027       1910
# 3                                      None  1910-ORMAF-000031       1910
# 4                                      None  1910-ORMAF-000025       1910
# ..                                      ...                ...        ...
# 211  {A4C9C635-54A3-4FDF-A8DE-5C8CBB748A2B}  2022-ORMAF-022252       2022
# 212  {87FDD0AB-7B6E-4941-A5AA-6174BE19C02B}  2022-ORPRD-000918       2022
# 213  {8C60E4DA-62F7-428A-ABE5-A661FCBC7D6E}  2022-ORMAF-002365       2022
# 214  {9579F4ED-281F-407D-99C0-9B28F8E7B423}  2022-ORMAF-002300       2022
# 215  {723C3126-056E-4BD9-96CE-518A85C80BEE}  2023-ORMAF-023078       2023
#
#     LOCAL_NUM              INCIDENT  ... SOURCE AGENCY FIRE_YEAR_  \
# 0        None          1910 Fire 28  ...   USFS   USFS       1910
# 1        None          1910 Fire 29  ...   USFS   USFS       1910
# 2        None          1910 Fire 27  ...   USFS   USFS       1910
# 3        None          1910 Fire 31  ...   USFS   USFS       1910
# 4        None          1910 Fire 25  ...   USFS   USFS       1910
# ..        ...                   ...  ...    ...    ...        ...
# 211      None               Wickiup  ...   USFS   USFS       2022
# 212    000918  COUGAR GULCH 0918 PR  ...  WFIGS    BLM       2022
# 213      None                Myrtle  ...   USFS   USFS       2022
# 214      None              Zolgmann  ...   USFS   USFS       2022
# 215      None           Lost Spring  ...   USFS   USFS       2023
#
#        Shape__Are    Shape__Len                                   FORID  \
# 0    1.658106e+08  53060.785589                                    None
# 1    4.130851e+08  84394.520424                                    None
# 2    1.524486e+08  48956.458053                                    None
# 3    9.766016e+07  36910.349331                                    None
# 4    1.765018e+08  51860.411857                                    None
# ..            ...           ...                                     ...
# 211  1.081425e+05   1451.628264  {5CFE250F-7AEE-4FC9-AB16-77A0FF552A82}
# 212  1.039576e+06   6283.640593  {443FED13-F520-4538-819C-C20BC93BDDD9}
# 213  1.157398e+03    148.727279  {EE441DBA-82BA-4CA0-9113-DD4DA0EB0379}
# 214  1.411641e+02     54.632114  {C734A54A-A7A7-4A22-94DD-A6BDFE103300}
# 215  1.494532e+05   2344.246930  {EEE4DD8D-C58C-4186-967E-D86EF28309D2}
#
#     OTHERID  index_right               FORESTNAME  \
# 0      None          0.0  Malheur National Forest
# 1      None          0.0  Malheur National Forest
# 2      None          0.0  Malheur National Forest
# 3      None          0.0  Malheur National Forest
# 4      None          0.0  Malheur National Forest
# ..      ...          ...                      ...
# 211    None          0.0  Malheur National Forest
# 212    None          0.0  Malheur National Forest
# 213    None          0.0  Malheur National Forest
# 214    None          0.0  Malheur National Forest
# 215    None          0.0  Malheur National Forest
#
#                                               geometry
# 0    POLYGON ((-13171332.211 5500377.617, -13171139...
# 1    POLYGON ((-13301937.82 5454895.413, -13309798....
# 2    POLYGON ((-13204840.04 5513395.884, -13204789....
# 3    POLYGON ((-13220752.497 5441600.566, -13220881...
# 4    POLYGON ((-13264432.376 5547406.561, -13267574...
# ..                                                 ...
# 211  POLYGON ((-13227252.361 5498701.761, -13226895...
# 212  POLYGON ((-13299370.024 5500692.172, -13299302...
# 213  POLYGON ((-13260955.114 5448711.897, -13260953...
# 214  POLYGON ((-13303668.246 5432299.531, -13303666...
# 215  MULTIPOLYGON (((-13189309.862 5490387.135, -13...
#
# [216 rows x 25 columns]

# %%
# Ensure Ig_Date is datetime
mtbs_points["Ig_Date"] = pd.to_datetime(mtbs_points["Ig_Date"], errors="coerce")

# Extract year and convert to integer, handling NaT safely
mtbs_points["Ig_Year"] = mtbs_points["Ig_Date"].dt.year.astype("Int64")  # nullable integer type

# %% [markdown]
# MTBS data are only available from 1984 on, so the lower date bound is effectively set at 1984. We set the upper bound at 2002 since that is 15-25 years post-outbreak and the direct effects of the outbreaks on fire are likely to be diminished if they exist at all.

# %%
# Ensure CRS matches
if mnf_fires_all.crs != mtbs_points.crs:
    mtbs_points = mtbs_points.to_crs(mnf_fires_all.crs)

# Drop 'index_right' if it exists
if 'index_right' in mnf_fires_all.columns:
    mnf_fires_all = mnf_fires_all.drop(columns='index_right')
if 'index_right' in mtbs_points.columns:
    mtbs_points = mtbs_points.drop(columns='index_right')
    
# Spatial join (within)
joined = gpd.sjoin(mnf_fires_all, mtbs_points, how="left", predicate="contains")

# Drop mismatched years
matched_years = joined[joined["Ig_Year"] == joined["FIRE_YEAR"]]

# Preview result
print(f"Joined features with matching years: {len(matched_years)}")
# Out:
# Joined features with matching years: 53

# %%
matched_years
# Out:
#      OBJECTID                           MAP_METHOD      DATE_CUR  \
# 28      63975                              Unknown  198608210000
# 29       3563                      Digitized-Other  200805290000
# 31       3675                                Other  200805290000
# 38       4512                                Other  200805290000
# 39      32468                                Other  200805290000
# 40      40142                                Other  200805290000
# 41      65010                          Hand Sketch  201508120000
# 45      32223                                Other  200805290000
# 46      65077                              Unknown  201308060000
# 47       3339                                Other  200805290000
# 48       3312                                Other  200805290000
# 49       3311                                Other  200805290000
# 50      65257                          Hand Sketch  201508120000
# 52      32473                                Other  200805290000
# 56      32471                                Other  200805290000
# 57      32441                                Other  200805290000
# 59      65210                              Unknown  201308060000
# 60       3711                                Other  200805290000
# 63       3322                                Other  200805290000
# 66      60604                          Hand Sketch  199408280000
# 67      60606                          Hand Sketch  199408280000
# 68       3333                                Other  200805290000
# 70       3670                                Other  200805290000
# 71       3241                                Other  200805290000
# 90       3239               GPS - Uncorrected Data  200805290000
# 91       3655          Photogrammetric Compilation  200805290000
# 92      32474               GPS - Uncorrected Data  200805290000
# 97      64257                              Unknown  200207120000
# 100     64295                              Unknown  200207150000
# 101      2784               GPS - Uncorrected Data  200805290000
# 102     64268                              Unknown  200207120000
# 104     64850                              Unknown  200207120000
# 116      3261               GPS - Uncorrected Data  200805290000
# 119     64282                              Unknown  200608190000
# 120     32218               GPS - Uncorrected Data  200805290000
# 121     64286                              Unknown  200608220000
# 146     62573                          GPS-Unknown  200806300000
# 148      3673          Photogrammetric Compilation  201004200000
# 149     64565                              Unknown  200907250000
# 150     64437                              Unknown  201009150000
# 151      3602     Remote Sensing Data - Base Level  201104080000
# 161      3591  GPS - Differentially Corrected Data  201302140000
# 162     67044                          GPS-Unknown  201801260000
# 167      3596     Remote Sensing Data - Base Level  201502100000
# 169      3657     Remote Sensing Data - Base Level  201502100000
# 170     65490                       Infrared Image  201501150000
# 172     65623                       Infrared Image  201601130000
# 176      3723     Remote Sensing Data - Base Level  201603010000
# 178      3215               GPS - Uncorrected Data  201607310000
# 188     32182                                Other  202003051031
# 194      1049                                Other  202201121720
# 200      1081                                Other  202201052220
# 209     81396                        Mixed Methods          2021
#
#                                               COMMENTS  \
# 28                                                None
# 29                                                None
# 31                                                None
# 38                                                None
# 39                                                None
# 40                                                None
# 41                                                None
# 45             From old Snow Mountain district library
# 46                                                None
# 47                                                None
# 48             From old Snow Mountain district library
# 49             From old Snow Mountain district library
# 50                                                None
# 52                                                None
# 56                                                None
# 57                                                None
# 59                                                None
# 60                                                None
# 63                                                None
# 66                                                None
# 67                                                None
# 68                                                None
# 70                                                None
# 71                                                None
# 90                                                None
# 91                                                None
# 92                                                None
# 97                                                None
# 100                                               None
# 101                                               None
# 102                                               None
# 104                                               None
# 116                                               None
# 119                                               None
# 120                                               None
# 121                                               None
# 146                                               None
# 148              Fire is known as OR-MAF-149 In NIFMID
# 149                                               None
# 150                                               None
# 151                               848 acres on FS Land
# 161  NO FIRE REPORT, TRIFOLD OR UNIT LOGS SUBMITTED...
# 162                                               None
# 167                                  Fire not in IRWIN
# 169                                  Fire not in IRWIN
# 170                                               None
# 172                                               None
# 176  Complex was comprised of Mason Spring and Berr...
# 178  Very smokey day made it difficult to clearly i...
# 188                   FIre was never put into FireStat
# 194                          24.9 miles South of Unity
# 200  10 miles North of Riley, East of Silver Creek ...
# 209                                               None
#
#                                      GEO_ID  \
# 28   {91333CBB-1719-477C-82A6-6E6BEAC0C7AE}
# 29   {2070BE74-A271-433B-BA02-4C2B5005CBC1}
# 31   {5F63E1F0-39AC-4DA1-AA71-D76149C9D9BC}
# 38   {71BBAD01-679F-4340-A397-CBAB397E7ED3}
# 39   {4C3A81D2-CDFE-445C-9152-4613A463C8EF}
# 40   {5F1E4DD6-E6CD-4ED9-952E-17F1A0E11A7E}
# 41   {4A2C1AD3-2BC0-4977-B2B7-77422177221A}
# 45   {C197950F-6E11-477F-82CF-CB3E91C2EB6A}
# 46   {7F2C13D7-370D-4C96-9895-AFEA82FB7EE8}
# 47   {5DA44F9E-C7B2-47B2-A9A9-5D7F0A39C1B4}
# 48   {5F283D30-BBE5-4B96-B3F5-0C1DC9940897}
# 49   {D74FBB06-25A8-4955-87B2-F74D34D53A43}
# 50   {CA3FE9C4-9C83-47E4-B740-5A5C751E6B46}
# 52   {4F0FDFBF-E45C-4ACC-B3EA-7F0A2174EDF2}
# 56   {7C9BF1C1-6CEA-4EA1-A270-38BE1D2CA74E}
# 57   {6F882CC0-9DA0-4214-AF51-93057E5BF40F}
# 59   {FCC63174-FB76-4C92-ACEB-2DF6A2B4043B}
# 60   {2937D0B4-72E7-47B9-BA5C-D61022E6FDD7}
# 63   {96E1C80D-EE07-4076-ABEF-8092220F94CD}
# 66   {DAD6DA11-87D5-4137-A2A0-5B63CDD026B4}
# 67   {9B1B88AB-69EE-4083-BF42-E291FF538AE7}
# 68   {931F1A74-A96A-4A5A-98F4-BAD0B5883FB9}
# 70   {956C1A83-E598-48FE-ABC9-782B5DB0E7AA}
# 71   {FB4D5E3F-19C0-42F1-BAE3-B2891D302F8F}
# 90   {8AC69262-FE73-4149-B1EF-923FFF04292D}
# 91   {9A08CB3C-B58F-415F-9067-3A9B48A0399B}
# 92   {2F294F74-22A8-42B1-8F1A-7C3530ACBA52}
# 97   {F7F64C5B-550F-4008-90B2-246815A37F40}
# 100  {FE4A26C6-D7CA-4FDC-A2C2-508804378AC7}
# 101  {08163E2C-CA0B-44E1-8932-9015BECC67E1}
# 102  {C3EA68C5-2AFB-4760-9208-33EC9D316CDC}
# 104  {51596E70-1A75-4137-8EF9-1690E20C049C}
# 116  {460DCAF6-A4A4-4812-8A1E-25F726701F3B}
# 119  {A3611593-0C0E-49EC-9989-8CB9CC034391}
# 120  {D185B697-DCAD-4F59-B889-04266F3BDF36}
# 121  {63545E01-0047-4772-9A14-BCEE674B4BAC}
# 146  {80C6BFA6-FB9E-4F58-94D0-A337F45B5BD5}
# 148  {7804C7A9-BF12-4336-B7D0-9CE8EC733813}
# 149  {BD3AC8EC-DEF0-46C8-A37C-2C44A0D53D20}
# 150  {909C625A-1106-48BF-AA9C-3D7A7BEB5EBE}
# 151  {35A26528-4B87-4FB7-8CED-480A2DDDD5BC}
# 161  {25CFA0C8-2464-4F47-A70B-A0EA66BB2B4A}
# 162  {E869591A-4B93-4257-A076-1C103B70C302}
# 167  {5FB8ECF9-19A2-4735-AC67-1263DFA95EE8}
# 169  {7EA17CB5-25D7-4266-B029-57E3D29B4318}
# 170  {7CB6F860-F263-4D03-8F9A-244301653A3F}
# 172  {5DF62BC1-0B09-49EA-9026-5A4A1C5B84D7}
# 176  {AAFAD12E-1AF6-4F3D-A442-ECEA014DE126}
# 178  {F121D7BB-0A74-4DB4-B439-D92C7F81448D}
# 188  {C21CE6E6-B90B-4C48-953E-83AD3A6E8A16}
# 194  {1DD5286B-8DB6-4802-8CC5-0988616938EF}
# 200  {0860B51B-261A-42C6-9234-DAFC00D36492}
# 209                                    None
#
#                                     IRWINID          UNQE_FIRE_  FIRE_YEAR  \
# 28                                     None   1986-ORPRD-000000       1986
# 29                                     None   1986-ORUMF-000033       1986
# 31                                     None                None       1986
# 38                                     None                None       1989
# 39                                     None   1989-ORWWF-000377       1989
# 40                                     None   1990-ORMAF-000064       1990
# 41                                     None   1990-ORBUD-000000       1990
# 45                                     None                None       1990
# 46                                     None   1990-ORBUD-000000       1990
# 47                                     None   1990-ORMAF-000069       1990
# 48                                     None   1990-ORMAF-000604       1990
# 49                                     None                None       1990
# 50                                     None   1990-ORBUD-000000       1990
# 52                                     None   1990-ORMAF-000135       1990
# 56                                     None   1994-ORMAF-000198       1994
# 57                                     None   1994-ORWWF-000242       1994
# 59                                     None  1994-OR952S-000000       1994
# 60                                     None   1994-ORMAF-000125       1994
# 63                                     None   1994-ORMAF-000238       1994
# 66                                     None   1994-ORVAD-000000       1994
# 67                                     None   1994-ORVAD-000000       1994
# 68                                     None                None       1994
# 70                                     None   1996-ORUMF-000047       1996
# 71                                     None   1996-ORMAF-000019       1996
# 90                                     None   2002-ORMAF-000052       2002
# 91                                     None   2002-ORMAF-000049       2002
# 92                                     None   2002-ORMAF-000048       2002
# 97                                     None   2002-ORPRD-000000       2002
# 100                                    None   2002-ORPRD-000000       2002
# 101                                    None   2002-ORMAF-000085       2002
# 102                                    None   2002-ORPRD-000000       2002
# 104                                    None   2002-ORPRD-000000       2002
# 116                                    None   2006-ORUMF-000092       2006
# 119                                    None   2006-ORPRD-000000       2006
# 120                                    None   2006-ORMAF-000267       2006
# 121                                    None   2006-ORPRD-000000       2006
# 146                                    None   2008-ORPRD-000000       2008
# 148                                    None   2009-ORMAF-000040       2009
# 149                                    None   2009-ORMAF-000000       2009
# 150                                    None   2010-ORPRD-000746       2010
# 151                                    None   2010-ORMAF-000112       2010
# 161                                    None   2012-ORMAF-000046       2012
# 162                                    None   2012-ORMAF-012257       2012
# 167                                    None   2014-ORMAF-000130       2014
# 169                                    None   2014-ORMAF-000047       2014
# 170  {25C83E45-5B19-4D04-B0D5-921EAB040475}   2014-ORPRD-000649       2014
# 172                                    None   2015-ORMAF-000000       2015
# 176                                    None   2015-ORMAF-000192       2015
# 178  {60FA077F-D08E-4F51-A0A7-B8DF892AA977}   2016-ORWWF-000582       2016
# 188  {6FB0FEFD-A96D-4F23-BD34-60936BFCD93F}   2019-ORMAF-019204       2019
# 194  {4D9483DE-6226-43F2-A362-04D630514DD3}   2021-ORMAF-021300       2021
# 200  {27806E09-76E8-4F0A-88D4-F019440037C6}   2021-ORBUD-002263       2021
# 209  {27806E09-76E8-4F0A-88D4-F019440037C6}   2021-ORBUD-002263       2021
#
#     LOCAL_NUM              INCIDENT  ... dNBR_offst dNBR_stdDv NoData_T  \
# 28          0          VERGES RANCH  ...       65.0    -9999.0   -970.0
# 29       None               Jumpoff  ...       65.0    -9999.0   -970.0
# 31       None             Deardorff  ...       53.0    -9999.0   -970.0
# 38       None               Glacier  ...      -22.0    -9999.0   -970.0
# 39       None         Monument Rock  ...      -45.0    -9999.0   -970.0
# 40       None       Whiting Springs  ...       48.0    -9999.0   -970.0
# 41          0              Buck Spr  ...       -5.0    -9999.0   -970.0
# 45       None          Pine Springs  ...      -16.0    -9999.0   -970.0
# 46          0    Pine Springs Basin  ...      -16.0    -9999.0   -970.0
# 47       None              Snowshoe  ...       32.0        0.0   -970.0
# 48       None                   604  ...      -27.0    -9999.0   -970.0
# 49       None          Buck Springs  ...       -5.0    -9999.0   -970.0
# 50          0            Whiting Sp  ...       48.0    -9999.0   -970.0
# 52       None        Sheep Mountain  ...      -34.0        4.0   -970.0
# 56       None                Powder  ...      -10.0    -9999.0   -970.0
# 57       None        Little Malheur  ...      -32.0       42.0   -970.0
# 59          0        Jordan Springs  ...      -34.0       34.0   -970.0
# 60       None           Indian Rock  ...      -20.0    -9999.0   -970.0
# 63       None                  Reed  ...      -20.0    -9999.0   -970.0
# 66          0                POWDER  ...      -10.0    -9999.0   -970.0
# 67          0              IRONSIDE  ...      -32.0       42.0   -970.0
# 68       None        Jordan Springs  ...      -34.0       34.0   -970.0
# 70       None                Summit  ...        0.0    -9999.0   -970.0
# 71       None               Wildcat  ...       38.0    -9999.0   -970.0
# 90       None          High Roberts  ...       21.0    -9999.0   -970.0
# 91       None                  Easy  ...       27.0    -9999.0   -970.0
# 92       None              Monument  ...       14.0    -9999.0   -970.0
# 97          0                  Easy  ...       27.0    -9999.0   -970.0
# 100         0              Flagtail  ...       24.0    -9999.0   -970.0
# 101      None              Flagtail  ...       24.0    -9999.0   -970.0
# 102         0          High Roberts  ...       21.0    -9999.0   -970.0
# 104         0              Monument  ...       14.0    -9999.0   -970.0
# 116      None          Sharps Ridge  ...        9.0    -9999.0   -970.0
# 119         0          Sharps Ridge  ...        9.0    -9999.0   -970.0
# 120      None           Thorn Creek  ...       -7.0    -9999.0   -970.0
# 121         0           Thorn Creek  ...       -7.0    -9999.0   -970.0
# 146         0      MURDERER'S CREEK  ...       15.0       28.0   -970.0
# 148      None          Cougar Creek  ...        1.0    -9999.0   -970.0
# 149         0          Cougar Creek  ...        1.0    -9999.0   -970.0
# 150       746       Cougar Mountain  ...      -15.0    -9999.0   -970.0
# 151      None       Cougar Mountain  ...      -15.0    -9999.0   -970.0
# 161     BM032          Parish Cabin  ...       47.0    -9999.0   -970.0
# 162     12257          Parish Cabin  ...       47.0    -9999.0   -970.0
# 167      None   Murders Creek South  ...      -26.0    -9999.0   -970.0
# 169      None          Bald Sisters  ...       -1.0    -9999.0   -970.0
# 170       649            South Fork  ...      -26.0    -9999.0   -970.0
# 172         0          Canyon Creek  ...        1.0       29.0   -970.0
# 176      None  Canyon Creek Complex  ...        1.0       29.0   -970.0
# 178       582                  Rail  ...      -21.0       25.0   -970.0
# 188     19204               204 Cow  ...      -25.0       16.0   -970.0
# 194      None           Black Butte  ...      -25.0       33.0   -970.0
# 200      None            Big Meadow  ...      -22.0       28.0   -970.0
# 209    002263            Big Meadow  ...      -22.0       28.0   -970.0
#
#      IncGreen_T  Low_T  Mod_T  High_T  \
# 28       -150.0   60.0  155.0   300.0
# 29       -150.0  150.0  350.0   600.0
# 31       -150.0  100.0  331.0   600.0
# 38       -150.0  100.0  304.0   550.0
# 39       -150.0  100.0  277.0   500.0
# 40       -150.0   75.0  322.0   600.0
# 41       -150.0   55.0  166.0   325.0
# 45       -150.0   55.0  193.0   375.0
# 46       -150.0   55.0  193.0   375.0
# 47       -150.0  120.0  258.0   450.0
# 48       -150.0   65.0  165.0   315.0
# 49       -150.0   55.0  166.0   325.0
# 50       -150.0   75.0  322.0   600.0
# 52       -150.0   70.0  293.0   550.0
# 56       -150.0   60.0  209.0   400.0
# 57       -150.0   16.0  242.0   491.0
# 59       -150.0   15.0  260.0   525.0
# 60       -150.0  120.0  247.0   430.0
# 63       -150.0  100.0  223.0   400.0
# 66       -150.0   60.0  209.0   400.0
# 67       -150.0   16.0  242.0   491.0
# 68       -150.0   15.0  260.0   525.0
# 70       -150.0  150.0  296.0   500.0
# 71       -150.0  150.0  296.0   500.0
# 90       -150.0  120.0  258.0   450.0
# 91       -150.0  120.0  339.0   600.0
# 92       -150.0  120.0  339.0   600.0
# 97       -150.0  120.0  339.0   600.0
# 100      -150.0  100.0  234.0   420.0
# 101      -150.0  100.0  234.0   420.0
# 102      -150.0  120.0  258.0   450.0
# 104      -150.0  120.0  339.0   600.0
# 116      -150.0  120.0  250.0   435.0
# 119      -150.0  120.0  250.0   435.0
# 120      -150.0  105.0  287.0   515.0
# 121      -150.0  105.0  287.0   515.0
# 146      -150.0   50.0  300.0  9999.0
# 148      -150.0   16.0  199.0   469.0
# 149      -150.0   16.0  199.0   469.0
# 150      -150.0   50.0  280.0  9999.0
# 151      -150.0   50.0  280.0  9999.0
# 161      -150.0  100.0  251.0   450.0
# 162      -150.0  100.0  251.0   450.0
# 167      -150.0   30.0  273.0   540.0
# 169      -150.0   50.0  230.0   510.0
# 170      -150.0   30.0  273.0   540.0
# 172      -150.0   50.0  222.0   430.0
# 176      -150.0   50.0  222.0   430.0
# 178      -150.0   50.0  216.0   420.0
# 188      -150.0   45.0  330.0   640.0
# 194      -150.0   26.0  258.0   515.0
# 200      -150.0   40.0  234.0   460.0
# 209      -150.0   40.0  234.0   460.0
#
#                                                Comment  ORIG_FID  Ig_Year
# 28                                                None    7815.0     1986
# 29                                                None    7817.0     1986
# 31                                                None    7814.0     1986
# 38                                                None    1408.0     1989
# 39                                                None    1413.0     1989
# 40                                                None    8662.0     1990
# 41                                                None    8726.0     1990
# 45                                                None    8661.0     1990
# 46                                                None    8661.0     1990
# 47                                                None    8723.0     1990
# 48                                                None    8725.0     1990
# 49                                                None    8726.0     1990
# 50                                                None    8662.0     1990
# 52                                                None    8724.0     1990
# 56                                                None    9716.0     1994
# 57                                                None    9717.0     1994
# 59                                                None   10089.0     1994
# 60                                                None    9715.0     1994
# 63                                                None    9718.0     1994
# 66                                                None    9716.0     1994
# 67                                                None    9717.0     1994
# 68                                                None   10089.0     1994
# 70                                                None   10439.0     1996
# 71                                                None   10434.0     1996
# 90                                                None   11554.0     2002
# 91                                                None   11553.0     2002
# 92                                                None   11552.0     2002
# 97                                                None   11553.0     2002
# 100                                               None   11692.0     2002
# 101                                               None   11692.0     2002
# 102                                               None   11554.0     2002
# 104                                               None   11552.0     2002
# 116                                               None   13020.0     2006
# 119                                               None   13020.0     2006
# 120  Scene pair not at peak of greeness  dnbr is sa...   13017.0     2006
# 121  Scene pair not at peak of greeness  dnbr is sa...   13017.0     2006
# 146                                               None   17145.0     2008
# 148                                               None   15335.0     2009
# 149                                               None   15335.0     2009
# 150                                               None   28919.0     2010
# 151                                               None   28919.0     2010
# 161                                               None   26640.0     2012
# 162                                               None   26640.0     2012
# 167                                               None   24988.0     2014
# 169                                               None   25252.0     2014
# 170                                               None   24988.0     2014
# 172  Used perimeter scene and edited GeoMAC perimet...   24517.0     2015
# 176  Used perimeter scene and edited GeoMAC perimet...   24517.0     2015
# 178                             Used GeoMAC perimeter.   23377.0     2016
# 188                                               None   20556.0     2019
# 194  Seven fire progressing images were applied whe...   19340.0     2021
# 200  Additionally the following images were applied...   19274.0     2021
# 209  Additionally the following images were applied...   19274.0     2021
#
# [53 rows x 49 columns]

# %%
# Add widget here

# %%
# Identify and reconcile overlapping fires
'''
Iterates through features to identify incidents that share the same year and have overlapping geometries.
Handles duplicate records for features with >90% overlapping geometries: Exact matches retain USFS record 
when applicable or larger incident, and non-exact matches with >90% overlap retain the larger incident. If there is <=90% overlap
and no match on INCIDENT, then the incident is added to a list for manual review.
Returns a gdf with duplicates removed and a gdf with a list of overlapping incident pairs for manual review.
'''
def process_overlapping_fires(gdf):
    gdf = gdf.copy()
    gdf["area"] = gdf.geometry.area  # Compute area for overlap calculations
    to_review = []
    to_remove = set()
    
    for i, fire in gdf.iterrows():
        overlapping_fires = gdf[
            (gdf['FIRE_YEAR'] == fire['FIRE_YEAR']) & 
            (gdf.index != i) & 
            (gdf.intersects(fire.geometry))
        ]  # Fires in the same year that intersect
        
        for j, overlap in overlapping_fires.iterrows():
            intersection_area = fire.geometry.intersection(overlap.geometry).area
            fire_overlap_pct = intersection_area / fire.area
            overlap_overlap_pct = intersection_area / overlap.area
            
            # Matching incident names
            if fire["INCIDENT"] == overlap["INCIDENT"]:
                if fire["AGENCY"] == "USFS":
                    to_remove.add(j)
                elif overlap["AGENCY"] == "USFS":
                    to_remove.add(i)
                else:
                    to_remove.add(i if fire["GIS_ACRES"] < overlap["GIS_ACRES"] else j)
            
            # >90% overlap
            elif fire_overlap_pct > 0.9 and overlap_overlap_pct > 0.9:
                if fire["AGENCY"] == "USFS":
                    to_remove.add(j)
                elif overlap["AGENCY"] == "USFS":
                    to_remove.add(i)
                else:
                    to_remove.add(i if fire["GIS_ACRES"] <= overlap["GIS_ACRES"] else j)
            
            # <90% overlap — add to review
            else:
                to_review.append({
                    "FIRE_YEAR": fire['FIRE_YEAR'],
                    "INCIDENT_1": fire['INCIDENT'], "AGENCY_1": fire['AGENCY'], "geometry_1": fire['geometry'],
                    "INCIDENT_2": overlap['INCIDENT'], "AGENCY_2": overlap['AGENCY'], "geometry_2": overlap['geometry']
                })
    
    gdf_cleaned = gdf.drop(index=list(to_remove)).copy()
    gdf_cleaned = gpd.GeoDataFrame(gdf_cleaned, geometry='geometry', crs=gdf.crs)  # Ensure it's a GeoDataFrame

    overlapping_mnf_fires = gpd.GeoDataFrame(to_review, geometry="geometry_1", crs=gdf.crs)
    return gdf_cleaned, overlapping_mnf_fires
    
mnf_fires_cleaned, overlapping_mnf_fires = process_overlapping_fires(matched_years)

# %%
# See which incidents remain after clearning duplicates
mnf_fires_cleaned.columns
# Out:
# Index(['OBJECTID', 'MAP_METHOD', 'DATE_CUR', 'COMMENTS', 'GEO_ID', 'IRWINID',
#        'UNQE_FIRE_', 'FIRE_YEAR', 'LOCAL_NUM', 'INCIDENT', 'UNIT_ID',
#        'POO_RESP_I', 'FEATURE_CA', 'GIS_ACRES', 'USER_NAME', 'SOURCE',
#        'AGENCY', 'FIRE_YEAR_', 'Shape__Are', 'Shape__Len', 'FORID', 'OTHERID',
#        'FORESTNAME', 'geometry', 'index_right', 'Event_ID', 'irwinID',
#        'Incid_Name', 'Incid_Type', 'Map_ID', 'Map_Prog', 'Asmnt_Type',
#        'BurnBndAc', 'BurnBndLat', 'BurnBndLon', 'Ig_Date', 'Pre_ID', 'Post_ID',
#        'Perim_ID', 'dNBR_offst', 'dNBR_stdDv', 'NoData_T', 'IncGreen_T',
#        'Low_T', 'Mod_T', 'High_T', 'Comment', 'ORIG_FID', 'Ig_Year', 'area'],
#       dtype='object')

# %%
mnf_fires_cleaned.plot()
# Out:
# <Axes: >

# %%
# These are the remaining incidents requiring manual review
overlapping_mnf_fires
# Out:
#    FIRE_YEAR       INCIDENT_1 AGENCY_1  \
# 0       1990  Whiting Springs     USFS
# 1       1990         Buck Spr      BLM
# 2       1990     Buck Springs     USFS
# 3       1990       Whiting Sp      BLM
#
#                                           geometry_1       INCIDENT_2  \
# 0  POLYGON ((-13252376.493 5426819.177, -13253831...       Whiting Sp
# 1  POLYGON ((-13316901.876 5429103.177, -13316916...     Buck Springs
# 2  POLYGON ((-13321212.071 5432729.181, -13321192...         Buck Spr
# 3  POLYGON ((-13254592.308 5423161.371, -13254692...  Whiting Springs
#
#   AGENCY_2                                         geometry_2
# 0      BLM  POLYGON ((-13254592.3085 5423161.3706, -132546...
# 1     USFS  POLYGON ((-13321212.071 5432729.1811, -1332119...
# 2      BLM  POLYGON ((-13316901.8765 5429103.177, -1331691...
# 3     USFS  POLYGON ((-13252376.4932 5426819.1774, -132538...

# %%
# Widget for manual review
def plot_feature_pair(row):
    fig, ax = plt.subplots(figsize=(10, 10))
    
#    color1 = agency_colors.get(row["AGENCY_1"], "gray")
#    color2 = agency_colors.get(row["AGENCY_2"], "gray")
    
    gpd.GeoSeries([row["geometry_1"]]).plot(ax=ax, edgecolor="black", alpha=0.7, hatch="xx", label=f"{row['INCIDENT_1']} ({row['AGENCY_1']})") # Hatch marked incident is the one listed first
    gpd.GeoSeries([row["geometry_2"]]).plot(ax=ax, color = "yellow", edgecolor="black", alpha=0.7, label=f"{row['INCIDENT_2']} ({row['AGENCY_2']})") # Yellow incident listed 2nd
    
    # Create legend
    
    plt.show()

def display_feature_pairs(gdf):
    dropdown = widgets.Dropdown(options=[(f"{row['INCIDENT_1']} vs {row['INCIDENT_2']}", i) for i, row in gdf.iterrows()], description="Feature Pair:")
    output = widgets.Output()
    def update_plot(change):
        output.clear_output()
        with output:
            plot_feature_pair(gdf.iloc[dropdown.value])
    dropdown.observe(update_plot, names='value')
    display(dropdown, output)
    update_plot({'name': 'value', 'new': 0})

display_feature_pairs(overlapping_mnf_fires)
# Out:
# Dropdown(description='Feature Pair:', options=(('Whiting Springs vs Whiting Sp', 0), ('Buck Spr vs Buck Spring…
# Output()

# %%
drop_list = ['Buck Spr', 'Whiting Springs']

# Drop specific incident names
mnf_fires_cleaned = mnf_fires_cleaned[~mnf_fires_cleaned["INCIDENT"].isin(drop_list)]
mnf_fires_cleaned
# Out:
#      OBJECTID                           MAP_METHOD      DATE_CUR  \
# 28      63975                              Unknown  198608210000
# 29       3563                      Digitized-Other  200805290000
# 31       3675                                Other  200805290000
# 38       4512                                Other  200805290000
# 39      32468                                Other  200805290000
# 45      32223                                Other  200805290000
# 47       3339                                Other  200805290000
# 48       3312                                Other  200805290000
# 49       3311                                Other  200805290000
# 50      65257                          Hand Sketch  201508120000
# 52      32473                                Other  200805290000
# 56      32471                                Other  200805290000
# 57      32441                                Other  200805290000
# 60       3711                                Other  200805290000
# 63       3322                                Other  200805290000
# 68       3333                                Other  200805290000
# 70       3670                                Other  200805290000
# 71       3241                                Other  200805290000
# 90       3239               GPS - Uncorrected Data  200805290000
# 91       3655          Photogrammetric Compilation  200805290000
# 92      32474               GPS - Uncorrected Data  200805290000
# 101      2784               GPS - Uncorrected Data  200805290000
# 116      3261               GPS - Uncorrected Data  200805290000
# 120     32218               GPS - Uncorrected Data  200805290000
# 146     62573                          GPS-Unknown  200806300000
# 148      3673          Photogrammetric Compilation  201004200000
# 151      3602     Remote Sensing Data - Base Level  201104080000
# 161      3591  GPS - Differentially Corrected Data  201302140000
# 167      3596     Remote Sensing Data - Base Level  201502100000
# 169      3657     Remote Sensing Data - Base Level  201502100000
# 176      3723     Remote Sensing Data - Base Level  201603010000
# 178      3215               GPS - Uncorrected Data  201607310000
# 188     32182                                Other  202003051031
# 194      1049                                Other  202201121720
# 200      1081                                Other  202201052220
#
#                                               COMMENTS  \
# 28                                                None
# 29                                                None
# 31                                                None
# 38                                                None
# 39                                                None
# 45             From old Snow Mountain district library
# 47                                                None
# 48             From old Snow Mountain district library
# 49             From old Snow Mountain district library
# 50                                                None
# 52                                                None
# 56                                                None
# 57                                                None
# 60                                                None
# 63                                                None
# 68                                                None
# 70                                                None
# 71                                                None
# 90                                                None
# 91                                                None
# 92                                                None
# 101                                               None
# 116                                               None
# 120                                               None
# 146                                               None
# 148              Fire is known as OR-MAF-149 In NIFMID
# 151                               848 acres on FS Land
# 161  NO FIRE REPORT, TRIFOLD OR UNIT LOGS SUBMITTED...
# 167                                  Fire not in IRWIN
# 169                                  Fire not in IRWIN
# 176  Complex was comprised of Mason Spring and Berr...
# 178  Very smokey day made it difficult to clearly i...
# 188                   FIre was never put into FireStat
# 194                          24.9 miles South of Unity
# 200  10 miles North of Riley, East of Silver Creek ...
#
#                                      GEO_ID  \
# 28   {91333CBB-1719-477C-82A6-6E6BEAC0C7AE}
# 29   {2070BE74-A271-433B-BA02-4C2B5005CBC1}
# 31   {5F63E1F0-39AC-4DA1-AA71-D76149C9D9BC}
# 38   {71BBAD01-679F-4340-A397-CBAB397E7ED3}
# 39   {4C3A81D2-CDFE-445C-9152-4613A463C8EF}
# 45   {C197950F-6E11-477F-82CF-CB3E91C2EB6A}
# 47   {5DA44F9E-C7B2-47B2-A9A9-5D7F0A39C1B4}
# 48   {5F283D30-BBE5-4B96-B3F5-0C1DC9940897}
# 49   {D74FBB06-25A8-4955-87B2-F74D34D53A43}
# 50   {CA3FE9C4-9C83-47E4-B740-5A5C751E6B46}
# 52   {4F0FDFBF-E45C-4ACC-B3EA-7F0A2174EDF2}
# 56   {7C9BF1C1-6CEA-4EA1-A270-38BE1D2CA74E}
# 57   {6F882CC0-9DA0-4214-AF51-93057E5BF40F}
# 60   {2937D0B4-72E7-47B9-BA5C-D61022E6FDD7}
# 63   {96E1C80D-EE07-4076-ABEF-8092220F94CD}
# 68   {931F1A74-A96A-4A5A-98F4-BAD0B5883FB9}
# 70   {956C1A83-E598-48FE-ABC9-782B5DB0E7AA}
# 71   {FB4D5E3F-19C0-42F1-BAE3-B2891D302F8F}
# 90   {8AC69262-FE73-4149-B1EF-923FFF04292D}
# 91   {9A08CB3C-B58F-415F-9067-3A9B48A0399B}
# 92   {2F294F74-22A8-42B1-8F1A-7C3530ACBA52}
# 101  {08163E2C-CA0B-44E1-8932-9015BECC67E1}
# 116  {460DCAF6-A4A4-4812-8A1E-25F726701F3B}
# 120  {D185B697-DCAD-4F59-B889-04266F3BDF36}
# 146  {80C6BFA6-FB9E-4F58-94D0-A337F45B5BD5}
# 148  {7804C7A9-BF12-4336-B7D0-9CE8EC733813}
# 151  {35A26528-4B87-4FB7-8CED-480A2DDDD5BC}
# 161  {25CFA0C8-2464-4F47-A70B-A0EA66BB2B4A}
# 167  {5FB8ECF9-19A2-4735-AC67-1263DFA95EE8}
# 169  {7EA17CB5-25D7-4266-B029-57E3D29B4318}
# 176  {AAFAD12E-1AF6-4F3D-A442-ECEA014DE126}
# 178  {F121D7BB-0A74-4DB4-B439-D92C7F81448D}
# 188  {C21CE6E6-B90B-4C48-953E-83AD3A6E8A16}
# 194  {1DD5286B-8DB6-4802-8CC5-0988616938EF}
# 200  {0860B51B-261A-42C6-9234-DAFC00D36492}
#
#                                     IRWINID         UNQE_FIRE_  FIRE_YEAR  \
# 28                                     None  1986-ORPRD-000000       1986
# 29                                     None  1986-ORUMF-000033       1986
# 31                                     None               None       1986
# 38                                     None               None       1989
# 39                                     None  1989-ORWWF-000377       1989
# 45                                     None               None       1990
# 47                                     None  1990-ORMAF-000069       1990
# 48                                     None  1990-ORMAF-000604       1990
# 49                                     None               None       1990
# 50                                     None  1990-ORBUD-000000       1990
# 52                                     None  1990-ORMAF-000135       1990
# 56                                     None  1994-ORMAF-000198       1994
# 57                                     None  1994-ORWWF-000242       1994
# 60                                     None  1994-ORMAF-000125       1994
# 63                                     None  1994-ORMAF-000238       1994
# 68                                     None               None       1994
# 70                                     None  1996-ORUMF-000047       1996
# 71                                     None  1996-ORMAF-000019       1996
# 90                                     None  2002-ORMAF-000052       2002
# 91                                     None  2002-ORMAF-000049       2002
# 92                                     None  2002-ORMAF-000048       2002
# 101                                    None  2002-ORMAF-000085       2002
# 116                                    None  2006-ORUMF-000092       2006
# 120                                    None  2006-ORMAF-000267       2006
# 146                                    None  2008-ORPRD-000000       2008
# 148                                    None  2009-ORMAF-000040       2009
# 151                                    None  2010-ORMAF-000112       2010
# 161                                    None  2012-ORMAF-000046       2012
# 167                                    None  2014-ORMAF-000130       2014
# 169                                    None  2014-ORMAF-000047       2014
# 176                                    None  2015-ORMAF-000192       2015
# 178  {60FA077F-D08E-4F51-A0A7-B8DF892AA977}  2016-ORWWF-000582       2016
# 188  {6FB0FEFD-A96D-4F23-BD34-60936BFCD93F}  2019-ORMAF-019204       2019
# 194  {4D9483DE-6226-43F2-A362-04D630514DD3}  2021-ORMAF-021300       2021
# 200  {27806E09-76E8-4F0A-88D4-F019440037C6}  2021-ORBUD-002263       2021
#
#     LOCAL_NUM              INCIDENT  ... dNBR_stdDv NoData_T IncGreen_T  \
# 28          0          VERGES RANCH  ...    -9999.0   -970.0     -150.0
# 29       None               Jumpoff  ...    -9999.0   -970.0     -150.0
# 31       None             Deardorff  ...    -9999.0   -970.0     -150.0
# 38       None               Glacier  ...    -9999.0   -970.0     -150.0
# 39       None         Monument Rock  ...    -9999.0   -970.0     -150.0
# 45       None          Pine Springs  ...    -9999.0   -970.0     -150.0
# 47       None              Snowshoe  ...        0.0   -970.0     -150.0
# 48       None                   604  ...    -9999.0   -970.0     -150.0
# 49       None          Buck Springs  ...    -9999.0   -970.0     -150.0
# 50          0            Whiting Sp  ...    -9999.0   -970.0     -150.0
# 52       None        Sheep Mountain  ...        4.0   -970.0     -150.0
# 56       None                Powder  ...    -9999.0   -970.0     -150.0
# 57       None        Little Malheur  ...       42.0   -970.0     -150.0
# 60       None           Indian Rock  ...    -9999.0   -970.0     -150.0
# 63       None                  Reed  ...    -9999.0   -970.0     -150.0
# 68       None        Jordan Springs  ...       34.0   -970.0     -150.0
# 70       None                Summit  ...    -9999.0   -970.0     -150.0
# 71       None               Wildcat  ...    -9999.0   -970.0     -150.0
# 90       None          High Roberts  ...    -9999.0   -970.0     -150.0
# 91       None                  Easy  ...    -9999.0   -970.0     -150.0
# 92       None              Monument  ...    -9999.0   -970.0     -150.0
# 101      None              Flagtail  ...    -9999.0   -970.0     -150.0
# 116      None          Sharps Ridge  ...    -9999.0   -970.0     -150.0
# 120      None           Thorn Creek  ...    -9999.0   -970.0     -150.0
# 146         0      MURDERER'S CREEK  ...       28.0   -970.0     -150.0
# 148      None          Cougar Creek  ...    -9999.0   -970.0     -150.0
# 151      None       Cougar Mountain  ...    -9999.0   -970.0     -150.0
# 161     BM032          Parish Cabin  ...    -9999.0   -970.0     -150.0
# 167      None   Murders Creek South  ...    -9999.0   -970.0     -150.0
# 169      None          Bald Sisters  ...    -9999.0   -970.0     -150.0
# 176      None  Canyon Creek Complex  ...       29.0   -970.0     -150.0
# 178       582                  Rail  ...       25.0   -970.0     -150.0
# 188     19204               204 Cow  ...       16.0   -970.0     -150.0
# 194      None           Black Butte  ...       33.0   -970.0     -150.0
# 200      None            Big Meadow  ...       28.0   -970.0     -150.0
#
#      Low_T  Mod_T  High_T                                            Comment  \
# 28    60.0  155.0   300.0                                               None
# 29   150.0  350.0   600.0                                               None
# 31   100.0  331.0   600.0                                               None
# 38   100.0  304.0   550.0                                               None
# 39   100.0  277.0   500.0                                               None
# 45    55.0  193.0   375.0                                               None
# 47   120.0  258.0   450.0                                               None
# 48    65.0  165.0   315.0                                               None
# 49    55.0  166.0   325.0                                               None
# 50    75.0  322.0   600.0                                               None
# 52    70.0  293.0   550.0                                               None
# 56    60.0  209.0   400.0                                               None
# 57    16.0  242.0   491.0                                               None
# 60   120.0  247.0   430.0                                               None
# 63   100.0  223.0   400.0                                               None
# 68    15.0  260.0   525.0                                               None
# 70   150.0  296.0   500.0                                               None
# 71   150.0  296.0   500.0                                               None
# 90   120.0  258.0   450.0                                               None
# 91   120.0  339.0   600.0                                               None
# 92   120.0  339.0   600.0                                               None
# 101  100.0  234.0   420.0                                               None
# 116  120.0  250.0   435.0                                               None
# 120  105.0  287.0   515.0  Scene pair not at peak of greeness  dnbr is sa...
# 146   50.0  300.0  9999.0                                               None
# 148   16.0  199.0   469.0                                               None
# 151   50.0  280.0  9999.0                                               None
# 161  100.0  251.0   450.0                                               None
# 167   30.0  273.0   540.0                                               None
# 169   50.0  230.0   510.0                                               None
# 176   50.0  222.0   430.0  Used perimeter scene and edited GeoMAC perimet...
# 178   50.0  216.0   420.0                             Used GeoMAC perimeter.
# 188   45.0  330.0   640.0                                               None
# 194   26.0  258.0   515.0  Seven fire progressing images were applied whe...
# 200   40.0  234.0   460.0  Additionally the following images were applied...
#
#      ORIG_FID  Ig_Year          area
# 28     7815.0     1986  1.236467e+07
# 29     7817.0     1986  1.089463e+07
# 31     7814.0     1986  7.490334e+06
# 38     1408.0     1989  7.373552e+07
# 39     1413.0     1989  9.980943e+07
# 45     8661.0     1990  5.550997e+08
# 47     8723.0     1990  9.332320e+07
# 48     8725.0     1990  1.061764e+07
# 49     8726.0     1990  1.609660e+08
# 50     8662.0     1990  4.261475e+07
# 52     8724.0     1990  8.659839e+07
# 56     9716.0     1994  4.565760e+07
# 57     9717.0     1994  8.148321e+07
# 60     9715.0     1994  1.131676e+07
# 63     9718.0     1994  1.872983e+07
# 68    10089.0     1994  4.496806e+07
# 70    10439.0     1996  3.045835e+08
# 71    10434.0     1996  8.414642e+07
# 90    11554.0     2002  1.069198e+08
# 91    11553.0     2002  4.646569e+07
# 92    11552.0     2002  1.938219e+08
# 101   11692.0     2002  6.410328e+07
# 116   13020.0     2006  4.396084e+07
# 120   13017.0     2006  1.149684e+08
# 146   17145.0     2008  1.117142e+07
# 148   15335.0     2009  8.413167e+06
# 151   28919.0     2010  1.628896e+07
# 161   26640.0     2012  5.068027e+07
# 167   24988.0     2014  5.222610e+08
# 169   25252.0     2014  2.356781e+07
# 176   24517.0     2015  8.711610e+08
# 178   23377.0     2016  3.296683e+08
# 188   20556.0     2019  7.784405e+07
# 194   19340.0     2021  1.815275e+08
# 200   19274.0     2021  2.047292e+07
#
# [35 rows x 50 columns]

# %% [markdown]
# 35 incidents remaining.

# %%
target_fires = mnf_fires_cleaned[mnf_fires_cleaned["Ig_Year"] <= 2002]

# %%
target_fires.columns
# Out:
# Index(['OBJECTID', 'MAP_METHOD', 'DATE_CUR', 'COMMENTS', 'GEO_ID', 'IRWINID',
#        'UNQE_FIRE_', 'FIRE_YEAR', 'LOCAL_NUM', 'INCIDENT', 'UNIT_ID',
#        'POO_RESP_I', 'FEATURE_CA', 'GIS_ACRES', 'USER_NAME', 'SOURCE',
#        'AGENCY', 'FIRE_YEAR_', 'Shape__Are', 'Shape__Len', 'FORID', 'OTHERID',
#        'FORESTNAME', 'geometry', 'index_right', 'Event_ID', 'irwinID',
#        'Incid_Name', 'Incid_Type', 'Map_ID', 'Map_Prog', 'Asmnt_Type',
#        'BurnBndAc', 'BurnBndLat', 'BurnBndLon', 'Ig_Date', 'Pre_ID', 'Post_ID',
#        'Perim_ID', 'dNBR_offst', 'dNBR_stdDv', 'NoData_T', 'IncGreen_T',
#        'Low_T', 'Mod_T', 'High_T', 'Comment', 'ORIG_FID', 'Ig_Year', 'area'],
#       dtype='object')

# %%
cols = ['FIRE_YEAR', 'Ig_Year', 'Ig_Date', 'INCIDENT', 'Incid_Name',  'AGENCY', 'Asmnt_Type',
       'BurnBndAc', 'BurnBndLat', 'BurnBndLon', 'Pre_ID', 'Post_ID',
       'Perim_ID', 'dNBR_offst', 'dNBR_stdDv', 'NoData_T', 'IncGreen_T',
       'Low_T', 'Mod_T', 'High_T', 'Comment', 'COMMENTS', 'ORIG_FID', 'area',
       'OBJECTID', 'MAP_METHOD', 'DATE_CUR', 'GEO_ID', 'IRWINID',
       'UNQE_FIRE_',  'LOCAL_NUM', 'UNIT_ID',
       'POO_RESP_I', 'FEATURE_CA', 'GIS_ACRES', 'USER_NAME', 'SOURCE',
       'FIRE_YEAR_', 'Shape__Are', 'Shape__Len', 'FORID', 'OTHERID',
       'FORESTNAME', 'geometry', 'index_right', 'Event_ID', 'irwinID',
       'Incid_Type', 'Map_ID', 'Map_Prog' ]
#cols = ['FIRE_YEAR', 'Ig_Year', 'Ig_Date', 'INCIDENT', 'Incid_Name',  'AGENCY', 'Asmnt_Type',
#       'Pre_ID', 'Post_ID',
#       'dNBR_offst', 'dNBR_stdDv', 'NoData_T', 'IncGreen_T',
#       'Low_T', 'Mod_T', 'High_T']

# %%
target_fires_remix = target_fires[cols]
target_fires_remix
# Out:
#      FIRE_YEAR  Ig_Year    Ig_Date        INCIDENT  \
# 28        1986     1986 1986-08-21    VERGES RANCH
# 29        1986     1986 1986-08-10         Jumpoff
# 31        1986     1986 1986-08-02       Deardorff
# 38        1989     1989 1989-07-27         Glacier
# 39        1989     1989 1989-07-28   Monument Rock
# 45        1990     1990 1990-08-06    Pine Springs
# 47        1990     1990 1990-07-13        Snowshoe
# 48        1990     1990 1990-08-06             604
# 49        1990     1990 1990-08-06    Buck Springs
# 50        1990     1990 1990-08-06      Whiting Sp
# 52        1990     1990 1990-08-06  Sheep Mountain
# 56        1994     1994 1994-08-28          Powder
# 57        1994     1994 1994-08-28  Little Malheur
# 60        1994     1994 1994-08-01     Indian Rock
# 63        1994     1994 1994-09-24            Reed
# 68        1994     1994 1994-08-27  Jordan Springs
# 70        1996     1996 1996-08-13          Summit
# 71        1996     1996 1996-07-26         Wildcat
# 90        2002     2002 2002-07-12    High Roberts
# 91        2002     2002 2002-07-12            Easy
# 92        2002     2002 2002-07-12        Monument
# 101       2002     2002 2002-07-15        Flagtail
#
#                               Incid_Name AGENCY Asmnt_Type  BurnBndAc  \
# 28                          VERGAS RANCH    BLM   Extended     1445.0
# 29                               JUMPOFF   USFS   Extended     1446.0
# 31                               UNNAMED   USFS   Extended     1017.0
# 38                       LITTLE BALDY MT   USFS   Extended     9801.0
# 39                         MONUMENT ROCK   USFS   Extended    11390.0
# 45                    PINE SPRINGS BASIN   USFS   Extended    71143.0
# 47                          CORRAL BASIN   USFS   Extended    12389.0
# 48                            SQUAW FLAT   USFS   Extended     1335.0
# 49                          BUCK SPRINGS   USFS   Extended    20969.0
# 50                       WHITING SPRINGS    BLM   Extended     5445.0
# 52                        SHEEP MOUNTAIN   USFS   Extended     9993.0
# 56       LITTLE MALHEUR COMPLEX (POWDER)   USFS   Extended     5902.0
# 57     LITTLE MALHEUR COMPLEX (IRONSIDE)   USFS   Extended    10435.0
# 60                           INDIAN ROCK   USFS   Extended     1553.0
# 63                                  REED   USFS   Extended     2754.0
# 68                        JORDAN SPRINGS   USFS   Extended     5998.0
# 70                 BULL COMPLEX (SUMMIT)   USFS   Extended    36318.0
# 71             WILDCAT COMPLEX (WILDCAT)   USFS   Extended    10674.0
# 90                         ROBERTS CREEK   USFS   Extended    14052.0
# 91                                  EASY   USFS   Extended     6399.0
# 92   MONUMENT-MALHEUR COMPLEX (MONUMENT)   USFS   Extended    23860.0
# 101                             FLAGTAIL   USFS   Extended     7991.0
#
#     BurnBndLat BurnBndLon  ... FORID OTHERID               FORESTNAME  \
# 28      43.737   -119.850  ...  None    None  Malheur National Forest
# 29      44.808   -118.724  ...  None    None  Malheur National Forest
# 31      44.380   -118.496  ...  None    None  Malheur National Forest
# 38      44.324   -118.478  ...  None    None  Malheur National Forest
# 39      44.348   -118.277  ...  None    None  Malheur National Forest
# 45      43.634   -119.352  ...  None    None  Malheur National Forest
# 47      44.247   -118.576  ...  None    None  Malheur National Forest
# 48      43.831   -119.546  ...  None    None  Malheur National Forest
# 49      43.711   -119.690  ...  None    None  Malheur National Forest
# 50      43.781   -119.049  ...  None    None  Malheur National Forest
# 52      44.238   -118.464  ...  None    None  Malheur National Forest
# 56      44.137   -118.269  ...  None    None  Malheur National Forest
# 57      44.261   -118.172  ...  None    None  Malheur National Forest
# 60      44.745   -118.701  ...  None    None  Malheur National Forest
# 63      44.699   -118.625  ...  None    None  Malheur National Forest
# 68      43.864   -118.727  ...  None    None  Malheur National Forest
# 70      44.729   -118.697  ...  None    None  Malheur National Forest
# 71      44.319   -118.718  ...  None    None  Malheur National Forest
# 90      44.279   -118.624  ...  None    None  Malheur National Forest
# 91      44.493   -118.497  ...  None    None  Malheur National Forest
# 92      44.288   -118.291  ...  None    None  Malheur National Forest
# 101     44.178   -119.183  ...  None    None  Malheur National Forest
#
#                                               geometry  index_right  \
# 28   POLYGON ((-13342653.655 5425990.58, -13342459....          3.0
# 29   POLYGON ((-13216250.308 5588771.989, -13216323...         41.0
# 31   POLYGON ((-13191564.817 5523388.755, -13191713...         30.0
# 38   POLYGON ((-13185096.453 5511146.029, -13185126...         27.0
# 39   POLYGON ((-13164043.784 5516602.055, -13164048...         28.0
# 45   POLYGON ((-13284244.515 5412897.496, -13284229...          1.0
# 47   POLYGON ((-13199244.948 5512696.342, -13199156...         14.0
# 48   POLYGON ((-13308934.071 5435999.672, -13308992...          5.0
# 49   POLYGON ((-13321212.071 5432729.181, -13321192...          4.0
# 50   POLYGON ((-13254592.308 5423161.371, -13254692...          7.0
# 52   POLYGON ((-13191219.548 5500453.583, -13191245...         13.0
# 56   POLYGON ((-13169731.431 5482641.191, -13169751...         11.0
# 57   POLYGON ((-13155002.73 5500587.685, -13155067....         15.0
# 60   POLYGON ((-13211045.724 5580431.403, -13211075...         40.0
# 63   POLYGON ((-13207845.308 5573961.632, -13207853...         37.0
# 68   MULTIPOLYGON (((-13220561.545 5442416.95, -132...          8.0
# 70   MULTIPOLYGON (((-13208418.444 5574728.24, -132...         38.0
# 71   MULTIPOLYGON (((-13213723.924 5518497.324, -13...         33.0
# 90   POLYGON ((-13200258.74 5511067.878, -13200277....         17.0
# 91   POLYGON ((-13190264.07 5545854.578, -13190215....         32.0
# 92   MULTIPOLYGON (((-13160579.716 5513835.445, -13...         18.0
# 101  POLYGON ((-13267277.767 5498105.648, -13267178...          9.0
#
#                   Event_ID  irwinID  Incid_Type      Map_ID  Map_Prog
# 28   OR4373711985019860821     None    Wildfire      5491.0      MTBS
# 29   OR4480811872419860810     None    Wildfire      5493.0      MTBS
# 31   OR4438011849619860802     None    Wildfire      5490.0      MTBS
# 38   OR4432411847819890727     None    Wildfire      6821.0      MTBS
# 39   OR4434811827719890728     None    Wildfire      6826.0      MTBS
# 45   OR4363411935219900806     None    Wildfire      7043.0      MTBS
# 47   OR4423611858019900713     None    Wildfire      7111.0      MTBS
# 48   OR4383111954619900806     None    Wildfire      7113.0      MTBS
# 49   OR4371111969019900806     None    Wildfire      7114.0      MTBS
# 50   OR4378111904919900806     None    Wildfire      7044.0      MTBS
# 52   OR4423611846619900806     None    Wildfire      7112.0      MTBS
# 56   OR4413711826919940828     None    Wildfire      8491.0      MTBS
# 57   OR4426111816919940828     None    Wildfire      8492.0      MTBS
# 60   OR4474511870119940801     None    Wildfire      8489.0      MTBS
# 63   OR4469911862519940924     None    Wildfire      8493.0      MTBS
# 68   OR4385711871719940827     None    Wildfire  10020118.0      MTBS
# 70   OR4472911869719960813     None    Wildfire      9481.0      MTBS
# 71   OR4431911871819960726     None    Wildfire      9476.0      MTBS
# 90   OR4427911862420020712     None    Wildfire     12652.0      MTBS
# 91   OR4449311849720020712     None    Wildfire     12651.0      MTBS
# 92   OR4428811829120020712     None    Wildfire     12650.0      MTBS
# 101  OR4417811918320020715     None    Wildfire     12802.0      MTBS
#
# [22 rows x 50 columns]

# %%
len(target_fires_remix)
# Out:
# 22

# %%
# Define colors for outlines and boundaries
edge_color = "#993300"  # Dark Orange (fire outlines)
boundary_edge_color = "#006400"  # Dark Green (Malheur boundary)


mnf_bounds = mnf_bounds.to_crs(epsg=3857)
big_mnf_fires = target_fires_remix.to_crs(epsg=3857)

# Normalize the FIRE_YEAR to a color scale
norm = mcolors.Normalize(vmin=big_mnf_fires["FIRE_YEAR"].min(), vmax=big_mnf_fires["FIRE_YEAR"].max())
cmap = cm.get_cmap("YlOrRd")  # Yellow-Orange-Red colormap for fire visualization

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot fire perimeters with color ramp based on FIRE_YEAR
for _, row in big_mnf_fires.iterrows():
    fire_color = cmap(norm(row["FIRE_YEAR"]))  # Get color based on year
    row_geometry = row["geometry"]
    gpd.GeoSeries(row_geometry).plot(ax=ax, color=fire_color, edgecolor=edge_color, alpha=0.6, linewidth=0.8)

# Plot Malheur National Forest boundary with no fill, only dark green outline
mnf_bounds.plot(ax=ax, color="none", edgecolor=boundary_edge_color, linewidth=2)

# Add basemap
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, zoom=10, alpha=0.8)

# Create colorbar for the FIRE_YEAR gradient
sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, orientation="vertical", fraction=0.03, pad=0.02)
cbar.set_label("Fire Year", fontsize=12)

# Add a custom legend for boundary
legend_patches = [
    mpatches.Patch(color="none", edgecolor=boundary_edge_color, label="Malheur National Forest Boundary", linewidth=2)
]
ax.legend(handles=legend_patches, loc="upper right")

# Title and axis labels
ax.set_title("Malheur National Forest Fire Incidents greater than 1,000 acres (1984-2002)", fontsize=14)

# Remove axis labels (optional, since basemap provides context)
ax.set_xticks([])
ax.set_yticks([])

# Show plot
plt.show()
# Out:
# /tmp/ipykernel_3441/1213006049.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("YlOrRd")  # Yellow-Orange-Red colormap for fire visualization
# /tmp/ipykernel_3441/1213006049.py:36: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   mpatches.Patch(color="none", edgecolor=boundary_edge_color, label="Malheur National Forest Boundary", linewidth=2)
