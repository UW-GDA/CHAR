# %% [markdown]
# # Preprocess MNF fire perimeters

# %% [markdown]
# This script was run locally to save space as the original fire perimeters shapefile from NIFC is large and covers the entire US. This script subset the historical fire perimeters to only those intersecting the MNF boundary. It then uses the geometry of those fire perimeters to subset the Monitoring Trends in Burn Severity records for MNF. Finally, it exports both subsetted datasets as GeoJSON.

# %% [markdown]
# ## Import packages

# %%
import geopandas as gpd
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import contextily as ctx

# %% [markdown]
# ## Extract and read in fire perimeter vector data

# %%
# File paths
fire_perimeters_zip_path = r"C:\Users\imire\OneDrive - UW\Documents\GDA567\disturbance_interaction_analysis\downloaded_data\historic_fire_perimeters\InterAgencyFirePerimeterHistory_All_Years_View.zip"
output_shp_folder_path = r"C:\Users\imire\OneDrive - UW\Documents\GDA567\disturbance_interaction_analysis\downloaded_data\historic_fire_perimeters"
output_mnf_subset_folder_path = r"C:\Users\imire\OneDrive - UW\Documents\GDA567\disturbance_interaction_analysis\extracted_mnf_subset"
mtbs_points_path = r"C:\Users\imire\OneDrive - UW\Documents\GDA567\disturbance_interaction_analysis\downloaded_data\mtbs\mtbs_fod_pts_data\mtbs_FODpoints_DD.shp"

# %%
# Define unzip to output location function
def unzip_folder(zip_path, extract_to): 
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print(f"Extracted to: {extract_to}")

# %%
unzip_folder(fire_perimeters_zip_path, output_shp_folder_path) # Unzip shp
# Out:
# Extracted to: C:\Users\imire\OneDrive - UW\Documents\GDA567\disturbance_interaction_analysis\downloaded_data\historic_fire_perimeters

# %%
fires_gdf = gpd.read_file(output_shp_folder_path + "\\InterAgencyFirePerimeterHistory_All_Years_View.shp")

# %%
fires_gdf.head()
# Out:
#    OBJECTID               MAP_METHOD      DATE_CUR COMMENTS  \
# 0         1  Infrared Interpretation  201812200931     None
# 1         2   GPS - Uncorrected Data  201812200931     None
# 2         3          Digitized-Other  201812200931     None
# 3         4          Digitized-Other  201812200931     None
# 4         5   GPS - Uncorrected Data  201812200931     None
#
#                                    GEO_ID  \
# 0  {F0C1D266-75BB-4CA5-9E6F-F310F5038E23}
# 1  {411C4683-1404-4631-B20B-8FD8E73F72C6}
# 2  {FFB2E84B-D807-4F2C-91AC-C50EE9EF702D}
# 3  {26F30670-C114-4D34-909E-2751E7B42DC7}
# 4  {53630F8B-3263-4442-A60E-5D1A353F04CD}
#
#                                   IRWINID         UNQE_FIRE_ FIRE_YEAR  \
# 0                                    None               None      2002
# 1                                    None  2012-COSJF-001108      2012
# 2                                    None               None      1998
# 3                                    None  2011-COSJF-000213      2011
# 4  {67132D49-B7F4-4211-8D72-DC2103A1826B}  2016-COSJF-000444      2016
#
#   LOCAL_NUM          INCIDENT  ... GIS_ACRES USER_NAME SOURCE  AGENCY  \
# 0      None  MISSIONARY RIDGE  ...  70480.83      None   USFS    USFS
# 1      None        COAL CREEK  ...     97.68      None   USFS    USFS
# 2      None  TURKEY CREEK WFU  ...    308.54      None   USFS    USFS
# 3      None         WILDHORSE  ...     14.87      None   USFS    USFS
# 4      None         LONG DRAW  ...   2142.83      None   USFS    USFS
#
#   FIRE_YEAR_    Shape__Are     Shape__Len  FORID  OTHERID  \
# 0       2002  4.525708e+08  279658.944677   None     None
# 1       2012  6.264264e+05    5170.317870   None     None
# 2       1998  1.969943e+06    8067.631188   None     None
# 3       2011  9.653684e+04    1265.594810   None     None
# 4       2016  1.383778e+07   17001.554406   None     None
#
#                                             geometry
# 0  MULTIPOLYGON (((-11974175.167 4511483.444, -11...
# 1  POLYGON ((-11898257.752 4485689.218, -11898245...
# 2  POLYGON ((-11957688.186 4465171.969, -11957685...
# 3  POLYGON ((-12110778.56 4561415.155, -12110786....
# 4  POLYGON ((-12063543.3 4532611.314, -12063516.5...
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Clean fire perimeter gdf

# %% [markdown]
# * Ensure "FIRE_YEAR" is numeric to allow arithmetic operations.
# * Remove records associated with invalid years "0", "1", and "9999."
# * Check that invalid records were dropped correctly.

# %%
# Convert FIRE_YEAR to numeric, handling any errors
fires_gdf["FIRE_YEAR"] = pd.to_numeric(fires_gdf["FIRE_YEAR"], errors = "coerce") # Convert fire year to numeric

# Get unique values as a sorted list
unique_years = sorted(fires_gdf["FIRE_YEAR"].unique()) # List unique values of year

# Exclude records from invalid years
excluded_years = {9999, 1, 0}
valid_incidents = fires_gdf[~fires_gdf["FIRE_YEAR"].isin(excluded_years)].sort_values(by = "FIRE_YEAR", ascending = True)

# %%
valid_incidents.head()
# Out:
#        OBJECTID MAP_METHOD      DATE_CUR  \
# 12447     12448      Other  200611020000
# 14219     14220      Other  200611020000
# 2631       2632      Other  200611020000
# 2607       2608      Other  200611020000
# 2641       2642      Other  200611020000
#
#                                                 COMMENTS  \
# 12447  Year burned determined by PNW using carbon dat...
# 14219  Year burned determined by PNW using carbon dat...
# 2631   Year burned determined by PNW using carbon dat...
# 2607   Year burned determined by PNW using carbon dat...
# 2641   Year burned determined by PNW using carbon dat...
#
#                                        GEO_ID IRWINID UNQE_FIRE_  FIRE_YEAR  \
# 12447  {A526C90F-6DE2-4296-8643-87B34452311C}    None       None        780
# 14219  {722D984E-DF48-4A96-AFDF-B938E86FE599}    None       None       1000
# 2631   {D83B067C-4385-4237-83D1-77C5DA8C22BA}    None       None       1000
# 2607   {F26FA54D-89EF-414A-80F5-7588A37F2A00}    None       None       1000
# 2641   {92B942E5-4D9D-4610-9961-69B7D512740B}    None       None       1000
#
#       LOCAL_NUM INCIDENT  ... GIS_ACRES USER_NAME SOURCE  AGENCY FIRE_YEAR_  \
# 12447      None  UNNAMED  ...   9309.31      None   USFS    USFS        780
# 14219      None  UNNAMED  ...      0.01      None   USFS    USFS       1000
# 2631       None  UNNAMED  ...   1505.66      None   USFS    USFS       1000
# 2607       None  UNNAMED  ...    129.56      None   USFS    USFS       1000
# 2641       None  UNNAMED  ...   2991.72      None   USFS    USFS       1000
#
#          Shape__Are    Shape__Len  FORID  OTHERID  \
# 12447  8.245466e+07  86883.156264   None     None
# 14219  1.154141e+02     85.096169   None     None
# 2631   1.380549e+07  18201.888885   None     None
# 2607   1.210874e+06   5867.130114   None     None
# 2641   2.718905e+07  31025.996617   None     None
#
#                                                 geometry
# 12447  MULTIPOLYGON (((-13754978.274 6026659.244, -13...
# 14219  POLYGON ((-13508198.41 6097117.203, -13508189....
# 2631   POLYGON ((-13483960.982 6170816.394, -13483983...
# 2607   POLYGON ((-13551342.83 6253654.238, -13551442....
# 2641   POLYGON ((-13465336.552 6132079.277, -13465324...
#
# [5 rows x 23 columns]

# %%
# Check valid incidents gdf
data_summary = {
    "all_records_count": len(fires_gdf),
    "valid_records_count": len(valid_incidents),
    "first_incident": valid_incidents.iloc[0]["INCIDENT"],
    "first_fire_year": valid_incidents.iloc[0]["FIRE_YEAR"],
    "last_incident": valid_incidents.iloc[-1]["INCIDENT"],
    "last_fire_year": valid_incidents.iloc[-1]["FIRE_YEAR"]
}

summary_text = '''The NIFC Historic Fire Perimeter dataset contains {all_records_count} records of which {valid_records_count} are labeled with a valid year.
The oldest valid record is for the {first_incident} incident {first_fire_year}. 
The newest valid record is for the {last_incident} incident in {last_fire_year}.
'''.format(**data_summary)

print(summary_text)
# Out:
# The NIFC Historic Fire Perimeter dataset contains 116365 records of which 116055 are labeled with a valid year.
# The oldest valid record is for the UNNAMED incident 780.
# The newest valid record is for the Oak incident in 2023.

# %% [markdown]
# ## Prepare to subset fires_gdf

# %% [markdown]
# * Extract all perimeters intersecting the boundary of Malheur National Forest (MNF).
# * Write perimeter features intersecting MNF to a GeoJSON.

# %%
mnf_bounds_gdf = gpd.read_file(r"C:\Users\imire\OneDrive - UW\Documents\GDA567\boundary_geoJSONs\malheur_bounds.geojson") # Read in gdf with Malheur National Forest boundary
mnf_bounds_gdf.columns
# Out:
# Index(['OBJECTID', 'ADMINFORES', 'REGION', 'FORESTNUMB', 'FORESTORGC',
#        'FORESTNAME', 'GIS_ACRES', 'SHAPELEN', 'SHAPEAREA', 'geometry'],
#       dtype='object')

# %%
mnf_bounds_gdf = mnf_bounds_gdf[["FORESTNAME", "geometry"]] # Drop all columns other than FORESTNAME and geometry

# %%
# Make sure CRS of mnf_bounds_gdf and fires_gdf are the same
if mnf_bounds_gdf.crs == fires_gdf.crs:
    print("Both datasets are in " + str(mnf_bounds_gdf.crs) + ".")
else:
    print("Datasets are not in same CRS.")

# Both already in Web Mercator
# Out:
# Both datasets are in EPSG:3857.

# %% [markdown]
# ## Filter fires_gdf to include only fires that overlap the Malheur NF boundary

# %%
# Perform spatial join to subset valid fires that overlapped the Malheur NF boundary
mnf_fires_all = gpd.sjoin(valid_incidents, mnf_bounds_gdf, how = "left", predicate = "intersects")
mnf_fires_all = mnf_fires_all[mnf_fires_all["FORESTNAME"] == "Malheur National Forest"].sort_values(by = "FIRE_YEAR", ascending = True)

# %%
mnf_fires_all.columns
# Out:
# Index(['OBJECTID', 'MAP_METHOD', 'DATE_CUR', 'COMMENTS', 'GEO_ID', 'IRWINID',
#        'UNQE_FIRE_', 'FIRE_YEAR', 'LOCAL_NUM', 'INCIDENT', 'UNIT_ID',
#        'POO_RESP_I', 'FEATURE_CA', 'GIS_ACRES', 'USER_NAME', 'SOURCE',
#        'AGENCY', 'FIRE_YEAR_', 'Shape__Are', 'Shape__Len', 'FORID', 'OTHERID',
#        'geometry', 'index_right', 'FORESTNAME'],
#       dtype='object')

# %%
mnf_record_count = len(mnf_fires_all)
mnf_first_fire_year = mnf_fires_all.iloc[0]["FIRE_YEAR"]
mnf_first_incident = mnf_fires_all.iloc[0]["INCIDENT"]
mnf_last_fire_year = mnf_fires_all.iloc[-1]["FIRE_YEAR"]
mnf_last_incident = mnf_fires_all.iloc[-1]["INCIDENT"]

# %%
# Define the dictionary with string keys
data_summary = {
    "mnf_record_count" :  mnf_record_count,
    "mnf_first_incident": mnf_first_incident,
    "mnf_first_fire_year": mnf_first_fire_year,
    "mnf_last_incident": mnf_last_incident,
    "mnf_last_fire_year": mnf_last_fire_year
}

# Format the text correctly
summary_text = '''The NIFC Historic Fire Perimeter dataset contains {mnf_record_count} valid records of fires with perimeters overlapping the Malneur National Forest boundary.
The oldest record is for the {mnf_first_incident} incident in {mnf_first_fire_year}. 
The newest record is for the {mnf_last_incident} incident in {mnf_last_fire_year}.
'''.format(**data_summary)

# Print the formatted text
print(summary_text)
# Out:
# The NIFC Historic Fire Perimeter dataset contains 216 valid records of fires with perimeters overlapping the Malneur National Forest boundary.
# The oldest record is for the 1910 Fire 28 incident in 1910.
# The newest record is for the Lost Spring incident in 2023.

# %%
# Group by year and count occurrences
fires_per_year = mnf_fires_all.groupby('FIRE_YEAR').size().reset_index(name = 'count')

year_range = pd.DataFrame({'FIRE_YEAR': range(1910, 2024)})
fires_per_year = year_range.merge(fires_per_year, on="FIRE_YEAR", how="left").fillna(0)
fires_per_year["count"] = fires_per_year["count"].astype(int)

plt.figure(figsize=(12, 6))
plt.bar(fires_per_year["FIRE_YEAR"], fires_per_year["count"])
plt.xlabel("Year")
plt.ylabel("Fire Count")
plt.title("Number of Fires Per Year in Malheur NF(1910-2023)")
tick_positions = np.arange(1910, 2025, 5)  # Every 5 years
plt.xticks(tick_positions, rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# The fires in 1910 and 1939 are well recorded and have sizable overlap with later fires, so they weill be kept in the dataset. However, the absence of records for the intervening years between records, especially prior to the 1950s, should not be assumed to indicate a lack of fire but instead a potential lack of /recorded/ fire. While the larger dataset does include fires going back to the 8th century mapped using carbon dating, there very well may be fires that occured within Malheur that went unrecorded or even unnoticed. While Malheur was designated a National Forest in 1908, it was not exactly a hot destination for recreators at the time. Future studies of historical sources or further investigation of natural markers of fire history (e.g., fire scars, pollen record, soil cores) may reveal unknown fires.
#
# However, it is also likely that there were in fact few to zero fires in the early 20th century due to the aggressive fire exclusion and suppression approaches to forest management employed by the Forest Service. Ultimately, it may not be possible to ever consider this dataset truly complete or known how close to complete it actually is. That being said, it is a rich source of spatially explicit data that allows us to begin untangling complex interactions between disturbance agents on a landscape.

# %%
# Define colors
fill_color = "#CC5500"  # Burnt Orange (fire perimeters)
edge_color = "#993300"  # Dark Orange (fire outlines)
boundary_edge_color = "#006400"  # Dark Green (Malheur boundary)

# Ensure GeoDataFrames are in Web Mercator (EPSG:3857) for basemap compatibility
mnf_fires_all = mnf_fires_all.to_crs(epsg=3857)
mnf_bounds_gdf = mnf_bounds_gdf.to_crs(epsg=3857)

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the fire perimeters
mnf_fires_all.plot(ax=ax, color=fill_color, edgecolor=edge_color, alpha=0.6, linewidth=0.8)

# Plot Malheur National Forest boundary with no fill, only dark green outline
mnf_bounds_gdf.plot(ax=ax, color="none", edgecolor=boundary_edge_color, linewidth=2)

# Add basemap
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, zoom=10, alpha=0.8)

# Add a custom legend
legend_patches = [
    mpatches.Patch(color=fill_color, label="Incident Perimeter", alpha=0.6, edgecolor=edge_color),
    mpatches.Patch(color="none", edgecolor=boundary_edge_color, label="Malheur National Forest Boundary", linewidth=2)
]
ax.legend(handles=legend_patches, loc="upper right")

# Title and axis labels
ax.set_title("All Malheur National Forest Fire Incidents (1910-2023)", fontsize=14)

# Remove axis labels (optional, since basemap provides context)
ax.set_xticks([])
ax.set_yticks([])

# Show plot
plt.show()
# Out:
# C:\Users\imire\AppData\Local\Temp\ipykernel_56872\1764623761.py:24: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   mpatches.Patch(color=fill_color, label="Incident Perimeter", alpha=0.6, edgecolor=edge_color),
# C:\Users\imire\AppData\Local\Temp\ipykernel_56872\1764623761.py:25: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   mpatches.Patch(color="none", edgecolor=boundary_edge_color, label="Malheur National Forest Boundary", linewidth=2)

# %% [markdown]
# ## Merge MTBS point attributes with fire perimeters

# %% [markdown]
# MTBS publishes a points dataset to supplement the burn severity mosaics. The points dataset has useful attributes like specific ignition date and dNBR offset values that we need for our analysis. Here, we'll subset the national dataset to the bounds of MNF for ease of processing.

# %%
mtbs_pts_gdf = gpd.read_file(mtbs_points_path)
mtbs_pts_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 30730 entries, 0 to 30729
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Event_ID    30730 non-null  object
#  1   irwinID     6576 non-null   object
#  2   Incid_Name  30730 non-null  object
#  3   Incid_Type  30730 non-null  object
#  4   Map_ID      30730 non-null  int64
#  5   Map_Prog    30730 non-null  object
#  6   Asmnt_Type  30730 non-null  object
#  7   BurnBndAc   30730 non-null  int64
#  8   BurnBndLat  30730 non-null  object
#  9   BurnBndLon  30730 non-null  object
#  10  Ig_Date     30730 non-null  datetime64[ms]
#  11  Pre_ID      22452 non-null  object
#  12  Post_ID     30730 non-null  object
#  13  Perim_ID    2878 non-null   object
#  14  dNBR_offst  30730 non-null  int64
#  15  dNBR_stdDv  30730 non-null  int64
#  16  NoData_T    30730 non-null  int64
#  17  IncGreen_T  30730 non-null  int64
#  18  Low_T       30730 non-null  int64
#  19  Mod_T       30730 non-null  int64
#  20  High_T      30730 non-null  int64
#  21  Comment     4572 non-null   object
#  22  ORIG_FID    30730 non-null  int64
#  23  geometry    30730 non-null  geometry
# dtypes: datetime64[ms](1), geometry(1), int64(10), object(12)
# memory usage: 5.6+ MB

# %%
# Ensure both gdfs use same CRS
if mtbs_pts_gdf.crs != mnf_fires_all.crs:
    mtbs_pts_gdf = mtbs_pts_gdf.to_crs(mnf_fires_all.crs)

mnf_mtbs_pts_gdf = gpd.clip(mtbs_pts_gdf, mnf_fires_all) # Clip MTBS pts to MNF geom

print(f"MTBS has {len(mnf_mtbs_pts_gdf)} incidents in their burn severity dataset within Malheur National Forest.")
# Out:
# MTBS has 43 incidents in their burn severity dataset within Malheur National Forest.

# %%
mnf_mtbs_pts_gdf
# Out:
#                     Event_ID                               irwinID  \
# 24847  OR4360111948420140714  4A17F8E0-6AA2-463D-A4F0-7643B1DDC9CA
# 8661   OR4363411935219900806                                  None
# 19274  OR4369211960520210910  27806E09-76E8-4F0A-88D4-F019440037C6
# 7815   OR4373711985019860821                                  None
# 8726   OR4371111969019900806                                  None
# 8725   OR4383111954619900806                                  None
# 6616   OR4382211938920070706                                  None
# 8662   OR4378111904919900806                                  None
# 10089  OR4385711871719940827                                  None
# 11692  OR4417811918320020715                                  None
# 19340  OR4408911832220210803  4D9483DE-6226-43F2-A362-04D630514DD3
# 9716   OR4413711826919940828                                  None
# 23383  OR4417011845020160926                                  None
# 8724   OR4423611846619900806                                  None
# 8723   OR4423611858019900713                                  None
# 9717   OR4426111816919940828                                  None
# 20556  OR4428511846020190809  6FB0FEFD-A96D-4F23-BD34-60936BFCD93F
# 11554  OR4427911862420020712                                  None
# 11552  OR4428811829120020712                                  None
# 26640  OR4417011876620120828                                  None
# 28919  OR4423911945520100915                                  None
# 24988  OR4426911945020140801                                  None
# 24517  OR4428411896120150812  8BD09462-6EC9-48E7-9856-DDBBE332ADFF
# 17145  OR4428911945420080630                                  None
# 12799  OR4430611944520060701                                  None
# 2697   OR4430811947319950915                                  None
# 27989  OR4431411944320111001                                  None
# 1408   OR4432411847819890727                                  None
# 1413   OR4434811827719890728                                  None
# 23377  OR4440811838320160731  60FA077F-D08E-4F51-A0A7-B8DF892AA977
# 7814   OR4438011849619860802                                  None
# 25252  OR4439111847320140803  545A381F-0F65-48CF-9A88-255F7062F730
# 11553  OR4449311849720020712                                  None
# 10434  OR4431911871819960726                                  None
# 15335  OR4432111890020090725                                  None
# 13017  OR4435711936420060821                                  None
# 13020  OR4481611875220060814                                  None
# 9718   OR4469911862519940924                                  None
# 10439  OR4472911869719960813                                  None
# 18158  OR4472811870820220822  40139450-A4E7-453F-9478-DDA7B402C8A2
# 9715   OR4474511870119940801                                  None
# 7817   OR4480811872419860810                                  None
# 3375   OR4387111971119990526                                  None
#
#                                 Incid_Name       Incid_Type    Map_ID  \
# 24847                              GUMBOOT         Wildfire     21286
# 8661                    PINE SPRINGS BASIN         Wildfire      7043
# 19274                           BIG MEADOW         Wildfire  10024084
# 7815                          VERGAS RANCH         Wildfire      5491
# 8726                          BUCK SPRINGS         Wildfire      7114
# 8725                            SQUAW FLAT         Wildfire      7113
# 6616                 EGLEY COMPLEX (EGLEY)         Wildfire     16202
# 8662                       WHITING SPRINGS         Wildfire      7044
# 10089                       JORDAN SPRINGS         Wildfire  10020118
# 11692                             FLAGTAIL         Wildfire     12802
# 19340                          BLACK BUTTE         Wildfire  10024225
# 9716       LITTLE MALHEUR COMPLEX (POWDER)         Wildfire      8491
# 23383                              UNNAMED  Prescribed Fire  10005307
# 8724                        SHEEP MOUNTAIN         Wildfire      7112
# 8723                          CORRAL BASIN         Wildfire      7111
# 9717     LITTLE MALHEUR COMPLEX (IRONSIDE)         Wildfire      8492
# 20556                              204 COW         Wildfire  10017072
# 11554                        ROBERTS CREEK         Wildfire     12652
# 11552  MONUMENT-MALHEUR COMPLEX (MONUMENT)         Wildfire     12650
# 26640                         PARISH CABIN         Wildfire      1747
# 28919                      COUGAR MOUNTAIN         Wildfire     19192
# 24988                   SOUTH FORK COMPLEX         Wildfire     22074
# 24517                 CANYON CREEK COMPLEX         Wildfire     25658
# 17145                                  242         Wildfire  10005975
# 12799                            TODD FIRE         Wildfire     14960
# 2697                       MURDERERS CREEK         Wildfire      9024
# 27989                      MURDERERS CREEK         Wildfire      4163
# 1408                       LITTLE BALDY MT         Wildfire      6821
# 1413                         MONUMENT ROCK         Wildfire      6826
# 23377                                 RAIL         Wildfire  10005286
# 7814                               UNNAMED         Wildfire      5490
# 25252                         BALD SISTERS         Wildfire     23203
# 11553                                 EASY         Wildfire     12651
# 10434            WILDCAT COMPLEX (WILDCAT)         Wildfire      9476
# 15335                           OR-MAF-149         Wildfire     18173
# 13017                          THORN CREEK         Wildfire     15194
# 13020                         SHARPS RIDGE         Wildfire     15197
# 9718                                  REED         Wildfire      8493
# 10439                BULL COMPLEX (SUMMIT)         Wildfire      9481
# 18158                        CROCKETS KNOB         Wildfire  10029556
# 9715                           INDIAN ROCK         Wildfire      8489
# 7817                               JUMPOFF         Wildfire      5493
# 3375                              W D LAKE  Prescribed Fire     10571
#
#       Map_Prog    Asmnt_Type  BurnBndAc BurnBndLat BurnBndLon  ... dNBR_offst  \
# 24847     MTBS       Initial       4609     43.594   -119.452  ...         13
# 8661      MTBS      Extended      71143     43.634   -119.352  ...        -16
# 19274     MTBS      Extended       2627     43.703   -119.548  ...        -22
# 7815      MTBS      Extended       1445     43.737   -119.850  ...         65
# 8726      MTBS      Extended      20969     43.711   -119.690  ...         -5
# 8725      MTBS      Extended       1335     43.831   -119.546  ...        -27
# 6616      MTBS      Extended     139515     43.822   -119.389  ...        -36
# 8662      MTBS      Extended       5445     43.781   -119.049  ...         48
# 10089     MTBS      Extended       5998     43.864   -118.727  ...        -34
# 11692     MTBS      Extended       7991     44.178   -119.183  ...         24
# 19340     MTBS      Extended      24736      44.12   -118.362  ...        -25
# 9716      MTBS      Extended       5902     44.137   -118.269  ...        -10
# 23383     MTBS       Initial       1416      44.17   -118.445  ...        -20
# 8724      MTBS      Extended       9993     44.238   -118.464  ...        -34
# 8723      MTBS      Extended      12389     44.247   -118.576  ...         32
# 9717      MTBS      Extended      10435     44.261   -118.172  ...        -32
# 20556     MTBS      Extended      10044     44.271   -118.442  ...        -25
# 11554     MTBS      Extended      14052     44.279   -118.624  ...         21
# 11552     MTBS      Extended      23860     44.288   -118.291  ...         14
# 26640     MTBS      Extended       6739     44.208   -118.747  ...         47
# 28919     MTBS       Initial       1865     44.239   -119.455  ...        -15
# 24988     MTBS       Initial      66743     44.274   -119.456  ...        -26
# 24517     MTBS      Extended     109786     44.301    -118.85  ...          1
# 17145     MTBS       Initial       1605     44.306    -119.44  ...         15
# 12799     MTBS       Initial       1073     44.306   -119.445  ...         52
# 2697      MTBS       Initial       1166     44.308   -119.473  ...        -33
# 27989     MTBS  Initial (SS)       1137     44.304   -119.423  ...      -9999
# 1408      MTBS      Extended       9801     44.324   -118.478  ...        -22
# 1413      MTBS      Extended      11390     44.348   -118.277  ...        -45
# 23377     MTBS      Extended      43813     44.348   -118.347  ...        -21
# 7814      MTBS      Extended       1017     44.380   -118.496  ...         53
# 25252     MTBS      Extended       3702     44.407   -118.465  ...         -1
# 11553     MTBS      Extended       6399     44.493   -118.497  ...         27
# 10434     MTBS      Extended      10674     44.319   -118.718  ...         38
# 15335     MTBS      Extended       1122     44.321   -118.900  ...          1
# 13017     MTBS      Extended      10678     44.357   -119.364  ...         -7
# 13020     MTBS      Extended       5550     44.816   -118.752  ...          9
# 9718      MTBS      Extended       2754     44.699   -118.625  ...        -20
# 10439     MTBS      Extended      36318     44.729   -118.697  ...          0
# 18158     MTBS       Initial       4676     44.735   -118.701  ...         11
# 9715      MTBS      Extended       1553     44.745   -118.701  ...        -20
# 7817      MTBS      Extended       1446     44.808   -118.724  ...         65
# 3375      MTBS       Initial       1956     43.871   -119.711  ...         -8
#
#       dNBR_stdDv NoData_T IncGreen_T  Low_T  Mod_T  High_T  \
# 24847      -9999     -970       -150     35   9999    9999
# 8661       -9999     -970       -150     55    193     375
# 19274         28     -970       -150     40    234     460
# 7815       -9999     -970       -150     60    155     300
# 8726       -9999     -970       -150     55    166     325
# 8725       -9999     -970       -150     65    165     315
# 6616       -9999     -970       -150    100    215     385
# 8662       -9999     -970       -150     75    322     600
# 10089         34     -970       -150     15    260     525
# 11692      -9999     -970       -150    100    234     420
# 19340         33     -970       -150     26    258     515
# 9716       -9999     -970       -150     60    209     400
# 23383         25     -970       -150     90    250    9999
# 8724           4     -970       -150     70    293     550
# 8723           0     -970       -150    120    258     450
# 9717          42     -970       -150     16    242     491
# 20556         16     -970       -150     45    330     640
# 11554      -9999     -970       -150    120    258     450
# 11552      -9999     -970       -150    120    339     600
# 26640      -9999     -970       -150    100    251     450
# 28919      -9999     -970       -150     50    280    9999
# 24988      -9999     -970       -150     30    273     540
# 24517         29     -970       -150     50    222     430
# 17145         28     -970       -150     50    300    9999
# 12799      -9999     -970       -150    150    223     365
# 2697       -9999     -970       -150     50   9999    9999
# 27989      -9999     9999       9999    200    -80   -9999
# 1408       -9999     -970       -150    100    304     550
# 1413       -9999     -970       -150    100    277     500
# 23377         25     -970       -150     50    216     420
# 7814       -9999     -970       -150    100    331     600
# 25252      -9999     -970       -150     50    230     510
# 11553      -9999     -970       -150    120    339     600
# 10434      -9999     -970       -150    150    296     500
# 15335      -9999     -970       -150     16    199     469
# 13017      -9999     -970       -150    105    287     515
# 13020      -9999     -970       -150    120    250     435
# 9718       -9999     -970       -150    100    223     400
# 10439      -9999     -970       -150    150    296     500
# 18158         26     -970       -150     50    400     800
# 9715       -9999     -970       -150    120    247     430
# 7817       -9999     -970       -150    150    350     600
# 3375       -9999     -970       -150     20    150    9999
#
#                                                  Comment  ORIG_FID  \
# 24847                                               None     24847
# 8661                                                None      8661
# 19274  Additionally the following images were applied...     19274
# 7815                                                None      7815
# 8726                                                None      8726
# 8725                                                None      8725
# 6616                                                None      6616
# 8662                                                None      8662
# 10089                                               None     10089
# 11692                                               None     11692
# 19340  Seven fire progressing images were applied whe...     19340
# 9716                                                None      9716
# 23383                                               None     23383
# 8724                                                None      8724
# 8723                                                None      8723
# 9717                                                None      9717
# 20556                                               None     20556
# 11554                                               None     11554
# 11552                                               None     11552
# 26640                                               None     26640
# 28919                                               None     28919
# 24988                                               None     24988
# 24517  Used perimeter scene and edited GeoMAC perimet...     24517
# 17145                                               None     17145
# 12799                                               None     12799
# 2697                                                None      2697
# 27989                                               none     27989
# 1408                                                None      1408
# 1413                                                None      1413
# 23377                             Used GeoMAC perimeter.     23377
# 7814                                                None      7814
# 25252                                               None     25252
# 11553                                               None     11553
# 10434                                               None     10434
# 15335                                               None     15335
# 13017  Scene pair not at peak of greeness  dnbr is sa...     13017
# 13020                                               None     13020
# 9718                                                None      9718
# 10439                                               None     10439
# 18158                                               None     18158
# 9715                                                None      9715
# 7817                                                None      7817
# 3375                                                None      3375
#
#                                 geometry
# 24847  POINT (-13297907.708 5402948.006)
# 8661    POINT (-13286246.627 5408981.07)
# 19274   POINT (-13307717.65 5419325.818)
# 7815   POINT (-13341691.938 5424800.457)
# 8726   POINT (-13322502.441 5425937.403)
# 8725   POINT (-13308454.919 5438497.226)
# 6616    POINT (-13295688.14 5424640.759)
# 8662   POINT (-13252430.082 5431620.118)
# 10089  POINT (-13215560.111 5443384.437)
# 11692  POINT (-13267390.956 5493001.528)
# 19340  POINT (-13176398.899 5484463.104)
# 9716   POINT (-13165692.957 5486724.512)
# 23383  POINT (-13184890.619 5491359.046)
# 8724    POINT (-13187615.173 5502000.53)
# 8723   POINT (-13200232.544 5502073.569)
# 9717        POINT (-13154501 5505875.35)
# 20556  POINT (-13183789.665 5507664.157)
# 11554  POINT (-13205173.952 5508655.944)
# 11552  POINT (-13168130.078 5510162.828)
# 26640  POINT (-13218434.702 5497243.046)
# 28919  POINT (-13298719.194 5503291.937)
# 24988  POINT (-13299327.208 5509433.871)
# 24517  POINT (-13229284.263 5510728.749)
# 17145  POINT (-13296162.035 5512715.452)
# 12799  POINT (-13296569.779 5512980.633)
# 2697   POINT (-13299647.036 5513241.743)
# 27989  POINT (-13294532.686 5514292.533)
# 1408    POINT (-13188872.94 5515707.248)
# 1413   POINT (-13166503.718 5519398.308)
# 23377  POINT (-13173842.588 5520848.992)
# 7814   POINT (-13190910.331 5524494.109)
# 25252   POINT (-13187745.72 5528316.807)
# 11553  POINT (-13191038.581 5542123.542)
# 10434  POINT (-13215646.394 5514946.757)
# 15335  POINT (-13235896.049 5515282.512)
# 13017  POINT (-13287521.499 5520826.847)
# 13020    POINT (-13219451.713 5592599.7)
# 9718    POINT (-13205234.61 5574275.121)
# 10439  POINT (-13213336.092 5578923.946)
# 18158   POINT (-13213513.03 5579796.109)
# 9715   POINT (-13213750.035 5581399.974)
# 7817   POINT (-13215011.758 5590763.769)
# 3375   POINT (-13326257.034 5446692.386)
#
# [43 rows x 24 columns]

# %%
# Export gdf to GeoJSON
mnf_fires_all.to_file(r"C:\Users\imire\OneDrive - UW\Documents\GDA567\mnf_fires_all.geojson", driver="GeoJSON")
mnf_mtbs_pts_gdf.to_file(r"C:\Users\imire\OneDrive - UW\Documents\GDA567\mnf_mtbs_pts.geojson", driver="GeoJSON")
